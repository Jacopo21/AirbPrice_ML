# %%
import pandas as pd
import numpy as np
import patsy
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import lars_path, LinearRegression, Lasso, LassoCV
from sklearn.metrics import r2_score, mean_squared_error
import scipy.stats as stats
import matplotlib.pyplot as plt
import math
import requests, io, re

from patsy import dmatrices
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import partial_dependence, permutation_importance, PartialDependenceDisplay
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %matplotlib inline

# %%
# Import data

data_oct = pd.read_csv("/Users/Admin/Desktop/listings_OCT_FINAL.csv")
#data_oct = pd.read_csv("/Users/jacopobinati/Desktop/HM2/listings_OCT_FINAL.csv")
data_oct.head()
# Out:
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1                NaN                  NaN                 f
# 2                NaN                  NaN                 f
# 3                NaN                  NaN                 f
# 4                NaN                 100%                 t
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        2.0
# 1                  1.0                        1.0
# 2                  1.0                        1.0
# 3                  1.0                        2.0
# 4                  1.0                        1.0
#
#                  host_verifications host_has_profile_pic  \
# 0                ['email', 'phone']                    t
# 1                ['email', 'phone']                    t
# 2                ['email', 'phone']                    t
# 3  ['email', 'phone', 'work_email']                    t
# 4                ['email', 'phone']                    t
#
#   host_identity_verified neighbourhood_cleansed neighbourhood_group_cleansed  \
# 0                      f               Bushwick                     Brooklyn
# 1                      t         Hell's Kitchen                    Manhattan
# 2                      f              Sunnyside                       Queens
# 3                      t     Bedford-Stuyvesant                     Brooklyn
# 4                      t     Bedford-Stuyvesant                     Brooklyn
#
#    ...  review_scores_value  calculated_host_listings_count  \
# 0  ...                 5.00                               1
# 1  ...                  NaN                               1
# 2  ...                  NaN                               1
# 3  ...                 5.00                               1
# 4  ...                 4.92                               1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           1
# 3                                           1
# 4                                           1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             0
#
#   calculated_host_listings_count_shared_rooms  reviews_per_month  ln_price  \
# 0                                           0               0.06  4.174387
# 1                                           0                NaN  4.700480
# 2                                           0                NaN  4.595120
# 3                                           0               0.03  4.248495
# 4                                           0               1.26  5.135798
#
#    property_House  property_Private room  property_Shared Room
# 0           False                   True                 False
# 1           False                   True                 False
# 2            True                  False                 False
# 3            True                  False                 False
# 4            True                  False                 False
#
# [5 rows x 46 columns]

# %%
#Drop columns that are not needed

columns_to_drop = ['host_verifications', 'latitude', 'longitude', 'host_listings_count',
                   'host_total_listings_count', 'maximum_nights_avg_ntm', 'minimum_minimum_nights', 'calendar_last_scraped',
                   'first_review']

data_oct.drop(columns_to_drop, axis=1, inplace=True)

# %%
# Keep obs with 2 < accommodates < 6, and property_House = 1 only

data_oct = data_oct[(data_oct['accommodates'] >= 2) & (data_oct['accommodates'] <= 6) & (data_oct['property_House'] == 1)]

# %%
# Formatting columns    
for binary in [
    "host_is_superhost",
    "host_has_profile_pic",
    "host_identity_verified",
    "has_availability",
]:
    data_oct[binary] = data_oct[binary].map({"t": True, "f": False})

data_oct["f_property_type"] = data_oct["property_type"].astype("category")
data_oct['f_neighbourhood_group_cleansed'] = data_oct['neighbourhood_group_cleansed'].astype("category")
data_oct["f_neighbourhood_cleansed"] = data_oct["neighbourhood_cleansed"].astype("category")
data_oct['n_bathroom'] = data_oct['bathrooms_text'].str.extract('(\d+\.?\d*)').astype(float)
data_oct['host_acceptance_rate'] = data_oct['host_acceptance_rate'].str.replace('%', '').astype(float)
data_oct['host_response_rate'] = data_oct['host_response_rate'].str.replace('%', '').astype(float)

# %%
# add new numeric columns from certain columns

numericals = [
    "accommodates",
    "availability_365",
    "review_scores_value",
    "number_of_reviews_ltm",
    "number_of_reviews_l30d",
    "review_scores_location",
    "review_scores_communication",
    "review_scores_checkin",
    "review_scores_cleanliness",
    "reviews_per_month",
    "minimum_nights",
    "maximum_nights",
    "beds",
    #"bedrooms",
    "host_acceptance_rate",
    "host_response_rate",
]

for col in numericals:
    data_oct["n_" + col] = pd.to_numeric(data_oct[col], errors="coerce")

# %%
#Assign mean values to missing ones

data_oct["n_review_scores_value"].fillna(data_oct["n_review_scores_value"].mean(), inplace=True)
data_oct["n_review_scores_location"].fillna(data_oct["n_review_scores_location"].mean(), inplace=True)
data_oct["n_review_scores_communication"].fillna(data_oct["n_review_scores_communication"].mean(), inplace=True)
data_oct["n_review_scores_checkin"].fillna(data_oct["n_review_scores_checkin"].mean(), inplace=True)
data_oct["n_reviews_per_month"].fillna(data_oct["n_reviews_per_month"].mean(), inplace=True)
#data_oct["n_bedrooms"].fillna(data_oct["n_bedrooms"].mean(), inplace=True)
data_oct["n_host_acceptance_rate"].fillna(data_oct["n_host_acceptance_rate"].mean(), inplace=True)
data_oct["n_host_response_rate"].fillna(data_oct["n_host_response_rate"].mean(), inplace=True)

data_oct = data_oct.assign(
    flag_review_scores_value=np.multiply(data_oct.n_review_scores_value.isna(), 1),
    n_review_scores_value=data_oct.n_review_scores_value.fillna(
        np.mean(data_oct.n_review_scores_value.dropna())
    ),
    flag_review_scores_location=np.multiply(data_oct.n_review_scores_location.isna(), 1),
    n_review_scores_location=data_oct.n_review_scores_location.fillna(
        np.mean(data_oct.n_review_scores_location.dropna())
    ),

    flag_review_scores_communication=np.multiply(data_oct.n_review_scores_communication.isna(), 1),
    n_review_scores_communication=data_oct.n_review_scores_communication.fillna(
        np.mean(data_oct.n_review_scores_communication.dropna())
    ),

    flag_review_scores_checkin=np.multiply(data_oct.n_review_scores_checkin.isna(), 1),
    n_review_scores_checkin=data_oct.n_review_scores_checkin.fillna(
        np.mean(data_oct.n_review_scores_checkin.dropna())
    ),

    flag_reviews_per_month=np.multiply(data_oct.n_reviews_per_month.isna(), 1),
    n_reviews_per_month=data_oct.n_reviews_per_month.fillna(
        np.mean(data_oct.n_reviews_per_month.dropna())
    ),

    flag_review_scores_cleanliness=np.multiply(data_oct.n_review_scores_cleanliness.isna(), 1),
    n_review_scores_cleanliness=data_oct.n_review_scores_cleanliness.fillna(
        np.mean(data_oct.n_review_scores_cleanliness.dropna())
    ),

    flag_host_acceptance_rate=np.multiply(data_oct.host_acceptance_rate.isna(), 1),
    n_host_acceptance_rate=data_oct.host_acceptance_rate.fillna(
        np.mean(data_oct.host_acceptance_rate.dropna())
    ),
    flag_host_response_rate=np.multiply(data_oct.host_response_rate.isna(), 1),
    n_host_response_rate=data_oct.host_response_rate.fillna(
        np.mean(data_oct.host_response_rate.dropna())
    )

)

# %%
 '''
    flag_bedrooms=np.multiply(data_oct.n_bedrooms.isna(), 1),
    n_bedrooms=data_oct.n_bedrooms.fillna(
        np.mean(data_oct.n_bedrooms.dropna())
    ),'''
# Out:
# '\n   flag_bedrooms=np.multiply(data_oct.n_bedrooms.isna(), 1),\n   n_bedrooms=data_oct.n_bedrooms.fillna(\n       np.mean(data_oct.n_bedrooms.dropna())\n   ),'

# %%
columns_to_check = ['n_bathroom', 'n_beds', 'host_has_profile_pic', 'host_is_superhost', 'host_identity_verified']
data_oct.dropna(subset=columns_to_check, inplace=True)

# %%
# Remove various strings, split amenities and turn into dtype:object

replace_str_dict = {
    '"' : "",
    ", " : ",",
    "\\\\" : "",
    ":" : "",
    "\\+" : "_",
}

data_oct["amenities"] = data_oct["amenities"].replace(replace_str_dict, regex=True).str.strip("[]").str.split(",")

# %%
# Function to merge amenities containing any keyword from a dictionary (case-insensitive)
def merge_items_with_keywords(amenities_list, merge_dict):
    merged_amenities = []
    for amenities in amenities_list:
        merged_item = []
        for amenity in amenities:
            lower_amenity = amenity.lower()
            for new_category, old_categories in merge_dict.items():
                if any(old_category in lower_amenity for old_category in old_categories):
                    merged_item.append(new_category)
                    break
            else:
                merged_item.append(amenity)
        merged_amenities.append(list(set(merged_item)))
    return merged_amenities

# %%
# Dictionary to merge amenities

merge_dict = {
    'wifi': ['wifi'],
    'kitchen': ['kitchen', 'kitchenette'],
    'stove': ['stove'],
    'oven': ['oven'],
    'microwave': ['microwave'],
    'refrigerator': ['refrigerator', 'fridge'],
    'dishwasher': ['dishwasher'],
    'kettel': ['kettle'],
    'toaster': ['toaster'],
    'coffee': ['coffee maker', 'machine', 'coffee', 'espresso', 'nespresso'],
    'tv': ['tv'],
    'sound_system': ['speaker', 'sound'],
    'game_console': ['game console', 'ps2', 'ps3', 'ps4', 'ps5', 
                     'playstation', 'wii', 'xbox'],
    'baby': ['baby', 'toys'],
    'body_wash': ['body', 'soap', 'shower gel'],
    'shampoo': ['shampoo'],
    'conditioner': ['conditioner'],
    'hair dryer': ['hair dryer'],
    'laundry': ['washer', 'laundry'],
    'backyard': ['backyard'],
    'grill': ['grill'],
    'breakfast': ['breakfast'],
    'clothing_storage': ['clothing storage'],
    'ac': ['ac - split type ductless system', 'air conditioning', 'central air conditioning', 'window ac unit'],
    'heating': ['heating']
}

# %%
# Merge some amenities together

data_oct['amenities'] = merge_items_with_keywords(data_oct['amenities'], merge_dict)

# %%
# Generate dummies by amenities

dummies = data_oct['amenities'].str.join('|').str.get_dummies()
dummies.columns = "d_" + dummies.columns.str.replace('/', '_').str.replace(' ', '_').str.replace('-', '_').str.replace('\\\\', '')

# %%
dummies.head()
# Out:
#     d_000_BTU_in_the_Bedroom_and_12  d_2_5_years_old  d_5_10_years_old  d_9  \
# 3                                 0                0                 0    0
# 4                                 0                0                 0    0
# 8                                 0                0                 0    0
# 9                                 0                0                 0    0
# 14                                0                0                 0    0
#
#     d_Amazon_Prime_Video  d_Avanti  d_Baking_sheet  d_Barbecue_utensils  \
# 3                      0         0               0                    0
# 4                      0         0               1                    0
# 8                      0         0               0                    0
# 9                      0         0               1                    0
# 14                     0         0               0                    0
#
#     d_Bathtub  d_Bay_view  ...  d_stationary_bike  d_stove  d_tesla_only  \
# 3           0           0  ...                  0        0             0
# 4           0           0  ...                  0        1             0
# 8           0           0  ...                  0        0             0
# 9           1           0  ...                  0        1             0
# 14          0           0  ...                  0        0             0
#
#     d_toaster  d_treadmill  d_tv  d_wardrobe  d_wifi  d_wood_burning  \
# 3           0            0     0           0       1               0
# 4           1            0     1           0       1               0
# 8           0            0     0           0       1               0
# 9           0            0     0           0       1               0
# 14          0            0     1           0       1               0
#
#     d_yoga_mat
# 3            0
# 4            0
# 8            0
# 9            0
# 14           0
#
# [5 rows x 357 columns]

# %%
# Top amenities in NYC
top_150_columns = dummies.sum().sort_values(ascending=False).head(150).index
final_dummies = dummies[top_150_columns]

# %%
final_dummies.head()
# Out:
#     d_wifi  d_kitchen  d_ac  d_Smoke_alarm  d_heating  d_tv  d_Essentials  \
# 3        1          1     1              1          1     0             1
# 4        1          1     1              1          1     1             1
# 8        1          1     1              1          1     0             1
# 9        1          1     1              0          1     0             1
# 14       1          0     1              1          1     1             1
#
#     d_Carbon_monoxide_alarm  d_Hangers  d_hair_dryer  ...  d_Beach_access  \
# 3                         1          1             1  ...               0
# 4                         1          1             1  ...               0
# 8                         0          0             0  ...               0
# 9                         0          1             1  ...               0
# 14                        0          0             1  ...               0
#
#     d_Exercise_equipment_yoga_mat  d_Paid_parking_lot_off_premises  \
# 3                               0                                0
# 4                               0                                0
# 8                               0                                0
# 9                               0                                0
# 14                              0                                0
#
#     d_Bread_maker  d_EV_charger  d_stationary_bike  \
# 3               0             0                  0
# 4               0             0                  0
# 8               0             0                  0
# 9               0             0                  0
# 14              0             0                  0
#
#     d_Pack_u2019n_play_Travel_crib___always_at_the_listing  \
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
#     d_Table_corner_guards  d_Bay_view  \
# 3                       0           0
# 4                       0           0
# 8                       0           0
# 9                       0           0
# 14                      0           0
#
#     d_Free_driveway_parking_on_premises_u2013_1_space
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
# [5 rows x 150 columns]

# %%
#Add dummies amneties to data_oct
data_oct = pd.concat([data_oct, final_dummies], axis=1)

# %%
data_oct.head()
# Out:
#     host_response_rate  host_acceptance_rate host_is_superhost  \
# 3                  NaN                   NaN             False
# 4                  NaN                 100.0              True
# 8                  NaN                   NaN             False
# 9                  NaN                   0.0             False
# 14               100.0                  99.0             False
#
#    host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 3                  True                   True     Bedford-Stuyvesant
# 4                  True                   True     Bedford-Stuyvesant
# 8                  True                   True               Kips Bay
# 9                  True                  False          Crown Heights
# 14                 True                   True           Williamsburg
#
#    neighbourhood_group_cleansed property_type  accommodates bathrooms_text  \
# 3                      Brooklyn         House             2         1 bath
# 4                      Brooklyn         House             4         1 bath
# 8                     Manhattan         House             2         1 bath
# 9                      Brooklyn         House             2         1 bath
# 14                     Brooklyn         House             2         1 bath
#
#     ...  d_Beach_access d_Exercise_equipment_yoga_mat  \
# 3   ...               0                             0
# 4   ...               0                             0
# 8   ...               0                             0
# 9   ...               0                             0
# 14  ...               0                             0
#
#     d_Paid_parking_lot_off_premises  d_Bread_maker  d_EV_charger  \
# 3                                 0              0             0
# 4                                 0              0             0
# 8                                 0              0             0
# 9                                 0              0             0
# 14                                0              0             0
#
#     d_stationary_bike  d_Pack_u2019n_play_Travel_crib___always_at_the_listing  \
# 3                   0                                                  0
# 4                   0                                                  0
# 8                   0                                                  0
# 9                   0                                                  0
# 14                  0                                                  0
#
#     d_Table_corner_guards  d_Bay_view  \
# 3                       0           0
# 4                       0           0
# 8                       0           0
# 9                       0           0
# 14                      0           0
#
#     d_Free_driveway_parking_on_premises_u2013_1_space
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
# [5 rows x 214 columns]

# %%
# Basic Variables inc neighnourhood
basic_vars = [
    "n_accommodates",
    #"n_bedrooms",
    "n_bathroom",
    "n_beds",
    #"f_neighbourhood_cleansed",
    'f_neighbourhood_group_cleansed',
    "n_availability_365",
    "n_minimum_nights",
    "n_maximum_nights",
    "host_is_superhost",
    "n_host_acceptance_rate",
    "host_has_profile_pic",
    "n_host_response_rate",
]

# reviews
reviews = [
    "n_review_scores_value",
    "flag_review_scores_value",
    "n_review_scores_location",
    "flag_review_scores_location",
    "n_review_scores_communication",
    "flag_review_scores_communication",
    "n_review_scores_checkin",
    "flag_review_scores_checkin",
    "n_review_scores_cleanliness",
    "flag_review_scores_cleanliness",
    "n_reviews_per_month",
    "flag_reviews_per_month"
]

# Dummy variables
amenities = [col for col in data_oct if col.startswith("d_")]

# interactions for the LASSO
# from ch14
X1 = [
    "n_accommodates:d_wifi",
    "d_breakfast:d_kitchen",
    "d_heating:n_accommodates",
    #"d_ac:n_bedrooms",
    "n_minimum_nights:n_accommodates",
    "n_availability_365:minimum_nights",
    "n_review_scores_value:n_reviews_per_month",
    "n_host_acceptance_rate:n_host_response_rate",
    "host_identity_verified:host_is_superhost",
]
# with neighbourhood
X2 = [
    "n_availability_365:f_neighbourhood_group_cleansed",
    "n_accommodates:f_neighbourhood_group_cleansed",
    "d_wifi:f_neighbourhood_group_cleansed",
    "d_Smoke_alarm:f_neighbourhood_group_cleansed",
]

# %%
predictors_1 = basic_vars
predictors_2 = basic_vars + reviews + amenities
predictors_3 = basic_vars + reviews + amenities + X1 + X2

# %%
amenities
# Out:
# ['d_wifi',
#  'd_kitchen',
#  'd_ac',
#  'd_Smoke_alarm',
#  'd_heating',
#  'd_tv',
#  'd_Essentials',
#  'd_Carbon_monoxide_alarm',
#  'd_Hangers',
#  'd_hair_dryer',
#  'd_Iron',
#  'd_Hot_water',
#  'd_refrigerator',
#  'd_shampoo',
#  'd_Dishes_and_silverware',
#  'd_Cooking_basics',
#  'd_coffee',
#  'd_Bed_linens',
#  'd_microwave',
#  'd_oven',
#  'd_stove',
#  'd_laundry',
#  'd_Dedicated_workspace',
#  'd_Self_check_in',
#  'd_Fire_extinguisher',
#  'd_Long_term_stays_allowed',
#  'd_Free_street_parking',
#  'd_Extra_pillows_and_blankets',
#  'd_First_aid_kit',
#  'd_Bathtub',
#  'd_body_wash',
#  'd_Cleaning_products',
#  'd_clothing_storage',
#  'd_Private_entrance',
#  'd_Freezer',
#  'd_dishwasher',
#  'd_Pets_allowed',
#  'd_Dining_table',
#  'd_Elevator',
#  'd_kettel',
#  'd_Wine_glasses',
#  'd_Dryer',
#  'd_Lockbox',
#  'd_toaster',
#  'd_conditioner',
#  'd_Laundromat_nearby',
#  'd_Room_darkening_shades',
#  'd_Security_cameras_on_property',
#  'd_Luggage_dropoff_allowed',
#  'd_Baking_sheet',
#  'd_backyard',
#  'd_Blender',
#  'd_Books_and_reading_material',
#  'd_Free_parking_on_premises',
#  'd_Outdoor_furniture',
#  'd_Gym',
#  'd_Outdoor_dining_area',
#  'd_Host_greets_you',
#  'd_Ethernet_connection',
#  'd_Portable_fans',
#  'd_grill',
#  'd_Free_dryer_u2013_In_unit',
#  'd_Keypad',
#  'd_Private_patio_or_balcony',
#  'd_Paid_parking_off_premises',
#  'd_Netflix',
#  'd_baby',
#  'd_Cleaning_available_during_stay',
#  'd_Single_level_home',
#  'd_Ceiling_fan',
#  'd_sound_system',
#  'd_Building_staff',
#  'd_City_skyline_view',
#  'd_Window_guards',
#  'd_Board_games',
#  'd_Smart_lock',
#  'd_Patio_or_balcony',
#  'd_Exercise_equipment',
#  'd_Paid_dryer_u2013_In_building',
#  'd_Drying_rack_for_clothing',
#  'd_Paid_parking_on_premises',
#  'd_Pack_u2019n_play_Travel_crib',
#  'd_Hulu',
#  'd_Crib',
#  'd_Paid_parking_garage_off_premises',
#  'd_Safe',
#  'd_HBO_Max',
#  'd_Rice_maker',
#  'd_Indoor_fireplace',
#  'd_Childrenu2019s_dinnerware',
#  'd_breakfast',
#  'd_Barbecue_utensils',
#  'd_High_chair',
#  'd_Garden_view',
#  'd_Disney_',
#  'd_Trash_compactor',
#  'd_Amazon_Prime_Video',
#  'd_Roku',
#  'd_Smoking_allowed',
#  'd_Mosquito_net',
#  'd_Shared_gym_in_building',
#  'd_Pool',
#  'd_Shared_patio_or_balcony',
#  'd_Bidet',
#  'd_Fire_pit',
#  'd_Outlet_covers',
#  'd_Hot_tub',
#  'd_Dryer_u2013_In_building',
#  'd_Courtyard_view',
#  'd_Dryer_u2013u00a0In_unit',
#  'd_standard_cable',
#  'd_and_dresser',
#  'd_game_console',
#  'd_Portable_heater',
#  'd_Free_dryer_u2013_In_building',
#  'd_Paid_street_parking_off_premises',
#  'd_Record_player',
#  'd_Piano',
#  'd_yoga_mat',
#  'd_Exercise_equipment_free_weights',
#  'd_Pack_u2019n_play_Travel_crib___available_upon_request',
#  'd_Pool_table',
#  'd_Crib___available_upon_request',
#  'd_Waterfront',
#  'd_wardrobe',
#  'd_Park_view',
#  'd_premium_cable',
#  'd_closet',
#  'd_River_view',
#  'd_Sun_loungers',
#  'd_Hammock',
#  'd_Bikes',
#  'd_french_press',
#  'd_Chromecast',
#  'd_Indoor_fireplace_electric',
#  'd_Changing_table',
#  'd_Beach_essentials',
#  'd_Public_or_shared_beach_access',
#  'd_Fireplace_guards',
#  'd_Private_hot_tub',
#  'd_Beach_access',
#  'd_Exercise_equipment_yoga_mat',
#  'd_Paid_parking_lot_off_premises',
#  'd_Bread_maker',
#  'd_EV_charger',
#  'd_stationary_bike',
#  'd_Pack_u2019n_play_Travel_crib___always_at_the_listing',
#  'd_Table_corner_guards',
#  'd_Bay_view',
#  'd_Free_driveway_parking_on_premises_u2013_1_space']

# %%
data_oct.to_csv('/Users/Admin/Desktop/listings_OCT_FINAL2.csv', index=False)

# %%
#Split the data
data_train, data_holdout = train_test_split(data_oct, train_size=0.8, random_state=42)

# %%
data_oct.head()
# Out:
#     host_response_rate  host_acceptance_rate host_is_superhost  \
# 3                  NaN                   NaN             False
# 4                  NaN                 100.0              True
# 8                  NaN                   NaN             False
# 9                  NaN                   0.0             False
# 14               100.0                  99.0             False
#
#    host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 3                  True                   True     Bedford-Stuyvesant
# 4                  True                   True     Bedford-Stuyvesant
# 8                  True                   True               Kips Bay
# 9                  True                  False          Crown Heights
# 14                 True                   True           Williamsburg
#
#    neighbourhood_group_cleansed property_type  accommodates bathrooms_text  \
# 3                      Brooklyn         House             2         1 bath
# 4                      Brooklyn         House             4         1 bath
# 8                     Manhattan         House             2         1 bath
# 9                      Brooklyn         House             2         1 bath
# 14                     Brooklyn         House             2         1 bath
#
#     ...  d_Beach_access d_Exercise_equipment_yoga_mat  \
# 3   ...               0                             0
# 4   ...               0                             0
# 8   ...               0                             0
# 9   ...               0                             0
# 14  ...               0                             0
#
#     d_Paid_parking_lot_off_premises  d_Bread_maker  d_EV_charger  \
# 3                                 0              0             0
# 4                                 0              0             0
# 8                                 0              0             0
# 9                                 0              0             0
# 14                                0              0             0
#
#     d_stationary_bike  d_Pack_u2019n_play_Travel_crib___always_at_the_listing  \
# 3                   0                                                  0
# 4                   0                                                  0
# 8                   0                                                  0
# 9                   0                                                  0
# 14                  0                                                  0
#
#     d_Table_corner_guards  d_Bay_view  \
# 3                       0           0
# 4                       0           0
# 8                       0           0
# 9                       0           0
# 14                      0           0
#
#     d_Free_driveway_parking_on_premises_u2013_1_space
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
# [5 rows x 214 columns]

# %% [markdown]
# # Random Forest

# %%
ncores = 3

# %%
rfr = RandomForestRegressor(
    random_state=42,
    criterion="squared_error",
    n_estimators=30,
    oob_score=True,
    n_jobs=-1,
)

tune_grid = {
    "max_features": [10, 12, 14],
    "min_samples_split": [6, 11, 16],
}

rf_random = GridSearchCV(
    rfr,
    tune_grid,
    cv=5,
    scoring="neg_root_mean_squared_error",
    verbose=3,
)

y, X = dmatrices("price ~ " + " + ".join(predictors_2), data_train)

rf_model_2 = rf_random.fit(X, y.ravel())
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_features=10, min_samples_split=6;, score=-176.205 total time=   0.3s
# [CV 2/5] END max_features=10, min_samples_split=6;, score=-342.716 total time=   0.3s
# [CV 3/5] END max_features=10, min_samples_split=6;, score=-257.193 total time=   0.3s
# [CV 4/5] END max_features=10, min_samples_split=6;, score=-291.349 total time=   0.3s
# [CV 5/5] END max_features=10, min_samples_split=6;, score=-208.492 total time=   0.3s
# [CV 1/5] END max_features=10, min_samples_split=11;, score=-171.838 total time=   0.2s
# [CV 2/5] END max_features=10, min_samples_split=11;, score=-342.431 total time=   0.2s
# [CV 3/5] END max_features=10, min_samples_split=11;, score=-261.404 total time=   0.2s
# [CV 4/5] END max_features=10, min_samples_split=11;, score=-290.765 total time=   0.2s
# [CV 5/5] END max_features=10, min_samples_split=11;, score=-209.760 total time=   0.2s
# [CV 1/5] END max_features=10, min_samples_split=16;, score=-173.851 total time=   0.2s
# [CV 2/5] END max_features=10, min_samples_split=16;, score=-344.064 total time=   0.2s
# [CV 3/5] END max_features=10, min_samples_split=16;, score=-258.931 total time=   0.2s
# [CV 4/5] END max_features=10, min_samples_split=16;, score=-290.895 total time=   0.2s
# [CV 5/5] END max_features=10, min_samples_split=16;, score=-208.276 total time=   0.2s
# [CV 1/5] END max_features=12, min_samples_split=6;, score=-173.392 total time=   0.3s
# [CV 2/5] END max_features=12, min_samples_split=6;, score=-343.703 total time=   0.3s
# [CV 3/5] END max_features=12, min_samples_split=6;, score=-257.305 total time=   0.3s
# [CV 4/5] END max_features=12, min_samples_split=6;, score=-289.661 total time=   0.3s
# [CV 5/5] END max_features=12, min_samples_split=6;, score=-210.964 total time=   0.3s
# [CV 1/5] END max_features=12, min_samples_split=11;, score=-171.003 total time=   0.2s
# [CV 2/5] END max_features=12, min_samples_split=11;, score=-344.291 total time=   0.2s
# [CV 3/5] END max_features=12, min_samples_split=11;, score=-257.711 total time=   0.3s
# [CV 4/5] END max_features=12, min_samples_split=11;, score=-290.705 total time=   0.2s
# [CV 5/5] END max_features=12, min_samples_split=11;, score=-206.532 total time=   0.2s
# [CV 1/5] END max_features=12, min_samples_split=16;, score=-171.760 total time=   0.2s
# [CV 2/5] END max_features=12, min_samples_split=16;, score=-344.299 total time=   0.2s
# [CV 3/5] END max_features=12, min_samples_split=16;, score=-257.765 total time=   0.2s
# [CV 4/5] END max_features=12, min_samples_split=16;, score=-290.469 total time=   0.2s
# [CV 5/5] END max_features=12, min_samples_split=16;, score=-209.723 total time=   0.2s
# [CV 1/5] END max_features=14, min_samples_split=6;, score=-171.752 total time=   0.4s
# [CV 2/5] END max_features=14, min_samples_split=6;, score=-343.227 total time=   0.4s
# [CV 3/5] END max_features=14, min_samples_split=6;, score=-257.845 total time=   0.4s
# [CV 4/5] END max_features=14, min_samples_split=6;, score=-289.784 total time=   0.3s
# [CV 5/5] END max_features=14, min_samples_split=6;, score=-208.651 total time=   0.4s
# [CV 1/5] END max_features=14, min_samples_split=11;, score=-169.762 total time=   0.4s
# [CV 2/5] END max_features=14, min_samples_split=11;, score=-342.126 total time=   0.3s
# [CV 3/5] END max_features=14, min_samples_split=11;, score=-259.130 total time=   0.3s
# [CV 4/5] END max_features=14, min_samples_split=11;, score=-292.222 total time=   0.3s
# [CV 5/5] END max_features=14, min_samples_split=11;, score=-205.682 total time=   0.4s
# [CV 1/5] END max_features=14, min_samples_split=16;, score=-170.990 total time=   0.3s
# [CV 2/5] END max_features=14, min_samples_split=16;, score=-342.739 total time=   0.4s
# [CV 3/5] END max_features=14, min_samples_split=16;, score=-257.616 total time=   0.3s
# [CV 4/5] END max_features=14, min_samples_split=16;, score=-291.176 total time=   0.3s
# [CV 5/5] END max_features=14, min_samples_split=16;, score=-208.399 total time=   0.3s

# %%
rfr = RandomForestRegressor(
    random_state=42,
    criterion="squared_error",
    n_estimators=30,
    oob_score=True,
    n_jobs=-1,
)

tune_grid = {
    "max_features": [10, 12, 14],
    "min_samples_split": [6, 11, 16],
}

rf_random = GridSearchCV(
    rfr,
    tune_grid,
    cv=5,
    scoring="neg_root_mean_squared_error",
    verbose=3,
)

y, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)

rf_model_3 = rf_random.fit(X, y.ravel())
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_features=10, min_samples_split=6;, score=-174.552 total time=   0.3s
# [CV 2/5] END max_features=10, min_samples_split=6;, score=-341.896 total time=   0.3s
# [CV 3/5] END max_features=10, min_samples_split=6;, score=-257.605 total time=   0.3s
# [CV 4/5] END max_features=10, min_samples_split=6;, score=-289.843 total time=   0.3s
# [CV 5/5] END max_features=10, min_samples_split=6;, score=-208.297 total time=   0.4s
# [CV 1/5] END max_features=10, min_samples_split=11;, score=-172.953 total time=   0.3s
# [CV 2/5] END max_features=10, min_samples_split=11;, score=-342.397 total time=   0.3s
# [CV 3/5] END max_features=10, min_samples_split=11;, score=-257.095 total time=   0.3s
# [CV 4/5] END max_features=10, min_samples_split=11;, score=-290.332 total time=   0.2s
# [CV 5/5] END max_features=10, min_samples_split=11;, score=-209.262 total time=   0.2s
# [CV 1/5] END max_features=10, min_samples_split=16;, score=-172.713 total time=   0.2s
# [CV 2/5] END max_features=10, min_samples_split=16;, score=-342.824 total time=   0.2s
# [CV 3/5] END max_features=10, min_samples_split=16;, score=-256.805 total time=   0.2s
# [CV 4/5] END max_features=10, min_samples_split=16;, score=-291.188 total time=   0.2s
# [CV 5/5] END max_features=10, min_samples_split=16;, score=-208.570 total time=   0.2s
# [CV 1/5] END max_features=12, min_samples_split=6;, score=-175.833 total time=   0.3s
# [CV 2/5] END max_features=12, min_samples_split=6;, score=-343.123 total time=   0.3s
# [CV 3/5] END max_features=12, min_samples_split=6;, score=-255.358 total time=   0.3s
# [CV 4/5] END max_features=12, min_samples_split=6;, score=-290.101 total time=   0.3s
# [CV 5/5] END max_features=12, min_samples_split=6;, score=-208.347 total time=   0.4s
# [CV 1/5] END max_features=12, min_samples_split=11;, score=-173.956 total time=   0.3s
# [CV 2/5] END max_features=12, min_samples_split=11;, score=-342.465 total time=   0.3s
# [CV 3/5] END max_features=12, min_samples_split=11;, score=-256.773 total time=   0.3s
# [CV 4/5] END max_features=12, min_samples_split=11;, score=-288.024 total time=   0.3s
# [CV 5/5] END max_features=12, min_samples_split=11;, score=-208.015 total time=   0.3s
# [CV 1/5] END max_features=12, min_samples_split=16;, score=-171.678 total time=   0.2s
# [CV 2/5] END max_features=12, min_samples_split=16;, score=-341.937 total time=   0.2s
# [CV 3/5] END max_features=12, min_samples_split=16;, score=-255.592 total time=   0.2s
# [CV 4/5] END max_features=12, min_samples_split=16;, score=-288.716 total time=   0.2s
# [CV 5/5] END max_features=12, min_samples_split=16;, score=-209.476 total time=   0.2s
# [CV 1/5] END max_features=14, min_samples_split=6;, score=-172.995 total time=   0.4s
# [CV 2/5] END max_features=14, min_samples_split=6;, score=-341.293 total time=   0.4s
# [CV 3/5] END max_features=14, min_samples_split=6;, score=-256.947 total time=   0.4s
# [CV 4/5] END max_features=14, min_samples_split=6;, score=-290.840 total time=   0.4s
# [CV 5/5] END max_features=14, min_samples_split=6;, score=-210.261 total time=   0.4s
# [CV 1/5] END max_features=14, min_samples_split=11;, score=-173.780 total time=   0.3s
# [CV 2/5] END max_features=14, min_samples_split=11;, score=-340.995 total time=   0.3s
# [CV 3/5] END max_features=14, min_samples_split=11;, score=-256.888 total time=   0.3s
# [CV 4/5] END max_features=14, min_samples_split=11;, score=-289.430 total time=   0.3s
# [CV 5/5] END max_features=14, min_samples_split=11;, score=-208.037 total time=   0.3s
# [CV 1/5] END max_features=14, min_samples_split=16;, score=-172.260 total time=   0.3s
# [CV 2/5] END max_features=14, min_samples_split=16;, score=-342.548 total time=   0.3s
# [CV 3/5] END max_features=14, min_samples_split=16;, score=-255.364 total time=   0.3s
# [CV 4/5] END max_features=14, min_samples_split=16;, score=-288.396 total time=   0.2s
# [CV 5/5] END max_features=14, min_samples_split=16;, score=-206.883 total time=   0.3s

# %%
pd.DataFrame(rf_model_2.cv_results_)[
    ["param_max_features", "param_min_samples_split", "mean_test_score"]
].assign(
    mean_test_score=lambda x: x["mean_test_score"] * -1,
    Variables=lambda x: x["param_max_features"],
    Min_nodes=lambda x: x["param_min_samples_split"] - 1,
).pivot(
    index="Min_nodes", columns="Variables", values="mean_test_score"
).round(
    2
)
# Out:
# Variables      10      12      14
# Min_nodes
# 5          255.19  255.00  254.25
# 10         255.24  254.05  253.78
# 15         255.20  254.80  254.18

# %%
pd.DataFrame(rf_model_3.cv_results_)[
    ["param_max_features", "param_min_samples_split", "mean_test_score"]
].assign(
    mean_test_score=lambda x: x["mean_test_score"] * -1,
    Variables=lambda x: x["param_max_features"],
    Min_nodes=lambda x: x["param_min_samples_split"] - 1,
).pivot(
    index="Min_nodes", columns="Variables", values="mean_test_score"
).round(
    2
)
# Out:
# Variables      10      12      14
# Min_nodes
# 5          254.44  254.55  254.47
# 10         254.41  253.85  253.83
# 15         254.42  253.48  253.09

# %%
pd.DataFrame(
    {
        "Min vars": [
            rf_model_2.best_estimator_.max_features,
            rf_model_3.best_estimator_.max_features,
        ],
        "Min nodes": [
            rf_model_2.best_estimator_.min_samples_split - 1,
            rf_model_3.best_estimator_.min_samples_split - 1,
        ],
    },
    ["RF 2", "RF 3"],
)
# Out:
#       Min vars  Min nodes
# RF 2        14         10
# RF 3        14         15

# %%
pd.DataFrame(
    {
        "RMSE": [
            rf_model_2.cv_results_["mean_test_score"].min(),
            rf_model_3.cv_results_["mean_test_score"].min(),
        ]
    },
    ["RF B", "RF C"],
).round(2) * -1
# Out:
#         RMSE
# RF B  255.24
# RF C  254.55

# %% [markdown]
# # OLS

# %%
data_oct.head()
# Out:
#     host_response_rate  host_acceptance_rate host_is_superhost  \
# 3                  NaN                   NaN             False
# 4                  NaN                 100.0              True
# 8                  NaN                   NaN             False
# 9                  NaN                   0.0             False
# 14               100.0                  99.0             False
#
#    host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 3                  True                   True     Bedford-Stuyvesant
# 4                  True                   True     Bedford-Stuyvesant
# 8                  True                   True               Kips Bay
# 9                  True                  False          Crown Heights
# 14                 True                   True           Williamsburg
#
#    neighbourhood_group_cleansed property_type  accommodates bathrooms_text  \
# 3                      Brooklyn         House             2         1 bath
# 4                      Brooklyn         House             4         1 bath
# 8                     Manhattan         House             2         1 bath
# 9                      Brooklyn         House             2         1 bath
# 14                     Brooklyn         House             2         1 bath
#
#     ...  d_Beach_access d_Exercise_equipment_yoga_mat  \
# 3   ...               0                             0
# 4   ...               0                             0
# 8   ...               0                             0
# 9   ...               0                             0
# 14  ...               0                             0
#
#     d_Paid_parking_lot_off_premises  d_Bread_maker  d_EV_charger  \
# 3                                 0              0             0
# 4                                 0              0             0
# 8                                 0              0             0
# 9                                 0              0             0
# 14                                0              0             0
#
#     d_stationary_bike  d_Pack_u2019n_play_Travel_crib___always_at_the_listing  \
# 3                   0                                                  0
# 4                   0                                                  0
# 8                   0                                                  0
# 9                   0                                                  0
# 14                  0                                                  0
#
#     d_Table_corner_guards  d_Bay_view  \
# 3                       0           0
# 4                       0           0
# 8                       0           0
# 9                       0           0
# 14                      0           0
#
#     d_Free_driveway_parking_on_premises_u2013_1_space
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
# [5 rows x 214 columns]

# %%
#print(data_oct[basic_vars].dtypes)
print(data_oct[reviews].dtypes)
# Out:
# n_review_scores_value               float64
# flag_review_scores_value              int32
# n_review_scores_location            float64
# flag_review_scores_location           int32
# n_review_scores_communication       float64
# flag_review_scores_communication      int32
# n_review_scores_checkin             float64
# flag_review_scores_checkin            int32
# n_review_scores_cleanliness         float64
# flag_review_scores_cleanliness        int32
# n_reviews_per_month                 float64
# flag_reviews_per_month                int32
# dtype: object

# %%
'''
y, X = dmatrices("price ~ " + " + ".join(predictors_1), data_train)
ols_model1 = LinearRegression().fit(X,y)
y_hat1 = ols_model1.predict(X)
ols_rmse1 = mean_squared_error(y,y_hat1,squared=False)

y_test, X_test = dmatrices("price ~ " + " + ".join(predictors_1), data_holdout)
ols_test1 = LinearRegression().fit(X_test,y_test)
y_hat_test1 = ols_test1.predict(X_test)
ols_cv_rmse1 = mean_squared_error(y_test,y_hat_test1,squared=False)
#-----------------------------------#

y, X = dmatrices("price ~ " + " + ".join(predictors_2), data_train)
ols_model2 = LinearRegression().fit(X,y)
y_hat2 = ols_model2.predict(X)
ols_rmse2 = mean_squared_error(y,y_hat2,squared=False)


y_test, X_test = dmatrices("price ~ " + " + ".join(predictors_2), data_holdout)
ols_test2 = LinearRegression().fit(X_test,y_test)
y_hat_test2 = ols_test2.predict(X_test)
ols_cv_rmse2 = mean_squared_error(y_test,y_hat_test2,squared=False)
#-----------------------------------#

y, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)
ols_model3 = LinearRegression().fit(X,y)
y_hat3 = ols_model3.predict(X)
ols_rmse3 = mean_squared_error(y,y_hat3,squared=False)

y_test, X_test = dmatrices("price ~ " + " + ".join(predictors_3), data_holdout)
ols_test3 = LinearRegression().fit(X_test,y_test)
y_hat_test3 = ols_test3.predict(X_test)
ols_cv_rmse3 = mean_squared_error(y_test,y_hat_test3,squared=False)
'''
# Out:
# '\ny, X = dmatrices("price ~ " + " + ".join(predictors_1), data_train)\nols_model1 = LinearRegression().fit(X,y)\ny_hat1 = ols_model1.predict(X)\nols_rmse1 = mean_squared_error(y,y_hat1,squared=False)\n\ny_test, X_test = dmatrices("price ~ " + " + ".join(predictors_1), data_holdout)\nols_test1 = LinearRegression().fit(X_test,y_test)\ny_hat_test1 = ols_test1.predict(X_test)\nols_cv_rmse1 = mean_squared_error(y_test,y_hat_test1,squared=False)\n#-----------------------------------#\n\ny, X = dmatrices("price ~ " + " + ".join(predictors_2), data_train)\nols_model2 = LinearRegression().fit(X,y)\ny_hat2 = ols_model2.predict(X)\nols_rmse2 = mean_squared_error(y,y_hat2,squared=False)\n\n\ny_test, X_test = dmatrices("price ~ " + " + ".join(predictors_2), data_holdout)\nols_test2 = LinearRegression().fit(X_test,y_test)\ny_hat_test2 = ols_test2.predict(X_test)\nols_cv_rmse2 = mean_squared_error(y_test,y_hat_test2,squared=False)\n#-----------------------------------#\n\ny, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)\nols_model3 = LinearRegression().fit(X,y)\ny_hat3 = ols_model3.predict(X)\nols_rmse3 = mean_squared_error(y,y_hat3,squared=False)\n\ny_test, X_test = dmatrices("price ~ " + " + ".join(predictors_3), data_holdout)\nols_test3 = LinearRegression().fit(X_test,y_test)\ny_hat_test3 = ols_test3.predict(X_test)\nols_cv_rmse3 = mean_squared_error(y_test,y_hat_test3,squared=False)\n'

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
def cross_validate(data, formula, model, kf):
    rmse_values = []
    for train_index, test_index in kf.split(data):
        data_train, data_test = data.iloc[train_index], data.iloc[test_index]

        y_train, X_train = patsy.dmatrices(formula, data_train)
        y_test, X_test = patsy.dmatrices(formula, data_test)

        results = model(y_train, X_train).fit()

        y_pred = results.predict(X_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        rmse_values.append(rmse)

    average_rmse = np.mean(rmse_values)
    return average_rmse

# %%
formulas = [
    ("OLS 1", "price ~ " + " + ".join(predictors_1)),
    ("OLS 2", "price ~ " + " + ".join(predictors_2)),
    ("OLS 3", "price ~ " + " + ".join(predictors_3))
]

rmse_values = []
for model_name, formula in formulas:
    rmse = cross_validate(data_oct, formula, sm.OLS, kf)
    rmse_values.append(rmse)

# %%
rmse_values
# Out:
# [441.91257927499225, 466.34757971536675, 424.53217543969487]

# %%
'''
formulas_ln = [
    ("Ln OLS 1", "ln_price ~ " + " + ".join(predictors_1)),
    ("Ln OLS 2", "ln_price ~ " + " + ".join(predictors_2)),
    ("Ln OLS 3", "ln_price ~ " + " + ".join(predictors_3))
]
'''
# Out:
# '\nformulas_ln = [\n    ("Ln OLS 1", "ln_price ~ " + " + ".join(predictors_1)),\n    ("Ln OLS 2", "ln_price ~ " + " + ".join(predictors_2)),\n    ("Ln OLS 3", "ln_price ~ " + " + ".join(predictors_3))\n]\n'

# %%
'''
ln_rmse_values = []
for model_name, formula in formulas_ln:
    ln_rmse = cross_validate(data_oct, formula, sm.OLS, kf)
    ln_rmse_values.append(ln_rmse)
'''
# Out:
# '\nln_rmse_values = []\nfor model_name, formula in formulas_ln:\n    ln_rmse = cross_validate(data_oct, formula, sm.OLS, kf)\n    ln_rmse_values.append(ln_rmse)\n'

# %%
#ln_rmse_values

# %% [markdown]
# # LASSO

# %%
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
lambdas = np.arange(0.05, 1.01, 0.05)
print(lambdas)
# Out:
# [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7
#  0.75 0.8  0.85 0.9  0.95 1.  ]

# %%
y, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)
X_featnames = X.design_info.column_names
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
lasso_fit = LassoCV(alphas=lambdas, cv=5, random_state=42).fit(X, y)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1563: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15850224.552206635, tolerance: 108758.0115800992
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99670.9609168768, tolerance: 82237.6844138221
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4745583.885017633, tolerance: 82237.6844138221
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12398114.446889043, tolerance: 96167.84713680847
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115805.92278957367, tolerance: 92410.46784208492
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6186167.2170984745, tolerance: 103645.49042871795
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
lasso_fit.alpha_
# Out:
# 1.0

# %%
rmse_lambda_folds = (
    pd.DataFrame(lasso_fit.mse_path_, index=lambdas[::-1])
    .apply(np.sqrt)
    .mean(axis=1)
    .to_frame(name="Test RMSE")
    .round(2)
)

# %%
'''
lasso_model = ElasticNet(l1_ratio=1, fit_intercept=True)

lasso_model_cv = GridSearchCV(
    lasso_model,
    {"alpha": [i / 100 for i in range(1, 26, 1)]},
    cv=5,
    scoring="neg_root_mean_squared_error",
    verbose=3,
    n_jobs=-1,
)

y, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)
y, X = np.array(y), np.array(X)

lasso_model_cv.fit(X, y.ravel())

lasso_rmse = (
    pd.DataFrame(lasso_model_cv.cv_results_)
    .loc[lambda x: x.param_alpha == lasso_model_cv.best_estimator_.alpha]
    .mean_test_score.values[0]
    * -1
)
'''
#lasso_rmse
# Out:
# '\nlasso_model = ElasticNet(l1_ratio=1, fit_intercept=True)\n\nlasso_model_cv = GridSearchCV(\n    lasso_model,\n    {"alpha": [i / 100 for i in range(1, 26, 1)]},\n    cv=5,\n    scoring="neg_root_mean_squared_error",\n    verbose=3,\n    n_jobs=-1,\n)\n\ny, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)\ny, X = np.array(y), np.array(X)\n\nlasso_model_cv.fit(X, y.ravel())\n\nlasso_rmse = (\n    pd.DataFrame(lasso_model_cv.cv_results_)\n    .loc[lambda x: x.param_alpha == lasso_model_cv.best_estimator_.alpha]\n    .mean_test_score.values[0]\n    * -1\n)\n'

# %% [markdown]
# # Final Comparison for October

# %%
rmse_values.extend([rmse_lambda_folds.loc[lasso_fit.alpha_].values[0], rf_model_2.cv_results_["mean_test_score"].min() * -1])
model_names = ['OLS 1', 'OLS 2', 'OLS 3', 'LASSO 1', 'RF 3']

df = pd.DataFrame({'Model': model_names, 'Test RMSE': rmse_values})

df['Test RMSE'] = df['Test RMSE'].round(2)

print(df)
# Out:
#      Model  Test RMSE
# 0    OLS 1     441.91
# 1    OLS 2     466.35
# 2    OLS 3     424.53
# 3  LASSO 1     256.55
# 4     RF 3     255.24

# %%
'''
rf_model_2_var_imp_df = (
    pd.DataFrame(
        rf_model_2.best_estimator_.feature_importances_, X.design_info.column_names
    )
    .reset_index()
    .rename({"index": "varname", 0: "imp"}, axis=1)
    .assign(
        imp_percentage=lambda x: x["imp"] / x["imp"].sum(),
        varname=lambda x: x.varname.str.replace(
            "f_room_type[T.", "Room type:", regex=False
        )
        .str.replace("f_neighbourhood_cleansed[T.", "Borough:", regex=False)
        .str.replace("]", "", regex=False),
    )
    .sort_values(by=["imp"], ascending=False)
)

'''
# Out:
# '\nrf_model_2_var_imp_df = (\n    pd.DataFrame(\n        rf_model_2.best_estimator_.feature_importances_, X.design_info.column_names\n    )\n    .reset_index()\n    .rename({"index": "varname", 0: "imp"}, axis=1)\n    .assign(\n        imp_percentage=lambda x: x["imp"] / x["imp"].sum(),\n        varname=lambda x: x.varname.str.replace(\n            "f_room_type[T.", "Room type:", regex=False\n        )\n        .str.replace("f_neighbourhood_cleansed[T.", "Borough:", regex=False)\n        .str.replace("]", "", regex=False),\n    )\n    .sort_values(by=["imp"], ascending=False)\n)\n\n'

# %%
'''
subset_df = rf_model_2_var_imp_df.iloc[:10, :]
color = ['blue']
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(subset_df['varname'], subset_df['imp_percentage'], color=color[0], s=60, label='Variable Importance')
for index, row in subset_df.iterrows():
    ax.plot([row['varname'], row['varname']], [0, row['imp_percentage']], color=color[0], linewidth=2)

ax.set_ylabel('Importance (Percent)')
ax.set_xlabel('Variable Name')
ax.set_title('Variable Importance')
plt.xticks(rotation=90)
ax.grid(True)
plt.tight_layout()
plt.show()
'''
# Out:
# "\nsubset_df = rf_model_2_var_imp_df.iloc[:10, :]\ncolor = ['blue']\nfig, ax = plt.subplots(figsize=(8, 6))\nax.scatter(subset_df['varname'], subset_df['imp_percentage'], color=color[0], s=60, label='Variable Importance')\nfor index, row in subset_df.iterrows():\n    ax.plot([row['varname'], row['varname']], [0, row['imp_percentage']], color=color[0], linewidth=2)\n\nax.set_ylabel('Importance (Percent)')\nax.set_xlabel('Variable Name')\nax.set_title('Variable Importance')\nplt.xticks(rotation=90)\nax.grid(True)\nplt.tight_layout()\nplt.show()\n"

# %% [markdown]
# # SHAP

# %%
import shap
from sklearn.preprocessing import PolynomialFeatures
from sklearn.compose import make_column_transformer
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
categorical_columns = [col for col in predictors_2 if col.startswith("f_")]
numerical_columns = [col for col in predictors_2 if col not in categorical_columns]

# %%
categorical_encoder = OneHotEncoder(handle_unknown="ignore")

preprocessing = ColumnTransformer(
    [
        ("cat", categorical_encoder, categorical_columns),
        ("num", "passthrough", numerical_columns),
    ]
)

rf_best_pipeline = Pipeline(
    [
        ("preprocess", preprocessing),
        ("regressor", rf_model_2.best_estimator_),
    ]
)

# %%
# Fit the ColumnTransformer on the training data
rf_best_pipeline["preprocess"].fit(data_holdout.filter(predictors_2))

# Now you can use it to transform the holdout data
X_encoded = rf_best_pipeline["preprocess"].transform(data_holdout.filter(predictors_2))

new_feature_names = [
    i.replace("cat__", "").replace("num__", "")
    for i in rf_best_pipeline["preprocess"].get_feature_names_out()
]

X_holdout = pd.DataFrame(X_encoded, columns=new_feature_names)
X_holdout = X_holdout.astype(int)

# %%
# Initialize a counter
counter = 0

# Print different categories in categorical columns for train and holdout sets
for col in categorical_columns:
    train_unique = set(data_train[col])
    holdout_unique = set(data_holdout[col])
    diff_categories = train_unique - holdout_unique
    if diff_categories:
        print(f"Different categories in {col}: {diff_categories}")
        counter += len(diff_categories)

print("Total number of different categories:", counter)
# Out:
# Total number of different categories: 0

# %%
for category in diff_categories:
    X_holdout[f"f_neighbourhood_cleansed_{category}"] = 0

# %%
#X_holdout['placeholder'] = 0

# %%
explainer = shap.Explainer(rf_best_pipeline["regressor"].predict, X_holdout)
shap_values = explainer(X_holdout)
# Out:
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 99/3718 [00:00<?, ?it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 102/3718 [00:10<03:03, 19.66it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 104/3718 [00:10<04:07, 14.62it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 106/3718 [00:10<04:44, 12.69it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 108/3718 [00:10<04:43, 12.71it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 110/3718 [00:10<04:45, 12.65it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 112/3718 [00:11<05:02, 11.91it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 114/3718 [00:11<05:05, 11.78it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 116/3718 [00:11<04:58, 12.05it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 118/3718 [00:11<05:00, 11.99it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 120/3718 [00:11<05:01, 11.93it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 122/3718 [00:11<04:48, 12.47it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 124/3718 [00:12<05:02, 11.90it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 126/3718 [00:12<05:03, 11.84it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 128/3718 [00:12<04:56, 12.11it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 130/3718 [00:12<04:58, 12.03it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 132/3718 [00:12<05:00, 11.93it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 134/3718 [00:12<04:55, 12.15it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 136/3718 [00:13<04:59, 11.95it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 138/3718 [00:13<05:02, 11.84it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 140/3718 [00:13<04:55, 12.09it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 142/3718 [00:13<04:51, 12.27it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 144/3718 [00:13<04:47, 12.41it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 146/3718 [00:13<04:45, 12.49it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 148/3718 [00:14<04:43, 12.60it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 150/3718 [00:14<04:59, 11.93it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 152/3718 [00:14<04:51, 12.22it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 154/3718 [00:14<05:04, 11.72it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 156/3718 [00:14<05:13, 11.37it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 158/3718 [00:14<05:03, 11.75it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 160/3718 [00:15<04:56, 11.98it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 162/3718 [00:15<04:56, 11.98it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 164/3718 [00:15<04:43, 12.52it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 166/3718 [00:15<04:48, 12.32it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 168/3718 [00:15<04:47, 12.37it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 170/3718 [00:15<04:42, 12.58it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 172/3718 [00:15<04:48, 12.29it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 174/3718 [00:16<04:55, 12.01it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 176/3718 [00:16<04:50, 12.20it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 178/3718 [00:16<04:54, 12.03it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 180/3718 [00:16<04:48, 12.26it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 182/3718 [00:16<04:53, 12.05it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 184/3718 [00:17<04:57, 11.88it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 186/3718 [00:17<04:51, 12.12it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 188/3718 [00:17<04:47, 12.27it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 190/3718 [00:17<04:43, 12.46it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 192/3718 [00:17<04:39, 12.62it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 194/3718 [00:17<04:38, 12.67it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 196/3718 [00:17<04:37, 12.70it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 198/3718 [00:18<04:35, 12.78it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 200/3718 [00:18<04:43, 12.42it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 202/3718 [00:18<04:41, 12.50it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 204/3718 [00:18<04:39, 12.57it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 206/3718 [00:18<04:39, 12.57it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 208/3718 [00:18<04:38, 12.62it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 210/3718 [00:19<04:45, 12.30it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 212/3718 [00:19<04:40, 12.48it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 214/3718 [00:19<04:45, 12.27it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 216/3718 [00:19<04:34, 12.75it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 218/3718 [00:19<04:41, 12.42it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 220/3718 [00:19<04:44, 12.29it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 222/3718 [00:20<04:49, 12.09it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 224/3718 [00:20<06:05,  9.55it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 226/3718 [00:20<05:38, 10.33it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 228/3718 [00:20<05:27, 10.66it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 230/3718 [00:20<05:19, 10.93it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 232/3718 [00:21<05:04, 11.45it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▋         | 234/3718 [00:21<04:54, 11.84it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▋         | 236/3718 [00:21<04:56, 11.74it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▋         | 238/3718 [00:21<04:58, 11.67it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▋         | 240/3718 [00:21<04:50, 11.98it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   7%|▋         | 242/3718 [00:21<04:53, 11.86it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   7%|▋         | 244/3718 [00:22<05:11, 11.15it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   7%|▋         | 246/3718 [00:22<05:00, 11.57it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   7%|▋         | 248/3718 [00:22<04:56, 11.70it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   7%|▋         | 250/3718 [00:22<04:50, 11.96it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   7%|▋         | 252/3718 [00:22<04:51, 11.89it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   7%|▋         | 254/3718 [00:22<04:45, 12.14it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   7%|▋         | 256/3718 [00:23<04:48, 12.01it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   7%|▋         | 258/3718 [00:23<04:36, 12.51it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# ...
# PermutationExplainer explainer:  98%|█████████▊| 3643/3718 [05:37<00:08,  9.34it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3644/3718 [05:37<00:07,  9.34it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3645/3718 [05:37<00:07,  9.37it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3646/3718 [05:37<00:08,  8.13it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3648/3718 [05:37<00:07,  8.94it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3649/3718 [05:37<00:08,  8.47it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3651/3718 [05:38<00:07,  9.23it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3652/3718 [05:38<00:07,  9.20it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3653/3718 [05:38<00:07,  9.22it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3654/3718 [05:38<00:06,  9.24it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3656/3718 [05:38<00:06,  9.52it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3658/3718 [05:38<00:06,  9.99it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3659/3718 [05:39<00:06,  9.33it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3660/3718 [05:39<00:06,  9.38it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3661/3718 [05:39<00:06,  9.31it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3662/3718 [05:39<00:06,  9.33it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3663/3718 [05:39<00:06,  8.85it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3664/3718 [05:39<00:06,  8.72it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3666/3718 [05:39<00:05,  9.49it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3667/3718 [05:39<00:05,  9.36it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3669/3718 [05:40<00:05,  9.56it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3671/3718 [05:40<00:04,  9.91it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3673/3718 [05:40<00:04, 10.15it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3675/3718 [05:40<00:04, 10.37it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3677/3718 [05:40<00:03, 10.50it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3679/3718 [05:41<00:03, 10.30it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3681/3718 [05:41<00:03, 10.48it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3683/3718 [05:41<00:03, 10.60it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3685/3718 [05:41<00:03,  9.86it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3687/3718 [05:41<00:03, 10.04it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3689/3718 [05:42<00:02, 10.01it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3691/3718 [05:42<00:02,  9.73it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3693/3718 [05:42<00:02, 10.24it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3695/3718 [05:42<00:02, 10.13it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3697/3718 [05:42<00:02, 10.02it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3699/3718 [05:42<00:01, 10.24it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3701/3718 [05:43<00:01, 10.33it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3703/3718 [05:43<00:01,  9.98it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3705/3718 [05:43<00:01,  9.99it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3707/3718 [05:43<00:01,  9.97it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3709/3718 [05:43<00:00, 10.43it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3711/3718 [05:44<00:00, 10.77it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3713/3718 [05:44<00:00, 10.72it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3715/3718 [05:44<00:00, 10.23it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3717/3718 [05:44<00:00, 10.11it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 3719it [05:44, 10.49it/s]

# %%
rf_best_pipeline["preprocess"].fit(data_train.filter(predictors_2))
X_encoded_train = rf_best_pipeline["preprocess"].transform(data_train.filter(predictors_2))

feature_names = [
    i.replace("cat__", "").replace("num__", "")
    for i in rf_best_pipeline["preprocess"].get_feature_names_out()
]

len(feature_names)
# Out:
# 387

# %%
feature_names = set(feature_names)

# %%
holdout_features_encoded = set(X_holdout.columns)
len(holdout_features_encoded)
# Out:
# 388

# %%
missing_features_encoded =  holdout_features_encoded - feature_names

for feature in missing_features_encoded:
    print(feature)
# Out:
# f_neighbourhood_cleansed_Lighthouse Hill

# %%
plt.figure(figsize=(10, 20))  # Adjust the size as needed
shap.plots.beeswarm(shap_values, max_display = 15, color=plt.get_cmap("viridis_r"), show=False)
plt.gcf().tight_layout()  # Adjust the layout to fit the feature names
plt.gcf().savefig('/Users/Admin/Desktop/oct_shap_beeswarm.png')

# %%
plt.figure(figsize=(10, 20))  # Adjust the size as needed
shap.plots.bar(shap_values, show=False)
plt.gcf().tight_layout()  # Adjust the layout to fit the feature names
plt.gcf().savefig('/Users/Admin/Desktop/oct_shap_bar.png')

# %%
plt.figure(figsize=(10, 20))  # Adjust the size as needed
shap.plots.waterfall(shap_values[2], show=False)
plt.gcf().tight_layout()  # Adjust the layout to fit the feature names
plt.gcf().savefig('/Users/Admin/Desktop/oct_shap_waterfall_2.png')
