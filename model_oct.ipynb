# %%
import pandas as pd
import numpy as np
import patsy
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import lars_path, LinearRegression, Lasso, LassoCV
from sklearn.metrics import r2_score, mean_squared_error
import scipy.stats as stats
import matplotlib.pyplot as plt
import math
import requests, io, re

from patsy import dmatrices
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import partial_dependence, permutation_importance, PartialDependenceDisplay
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %matplotlib inline

# %%
# Import data

data_oct = pd.read_csv("/Users/Admin/Desktop/listings_OCT_FINAL.csv")
#data_oct = pd.read_csv("/Users/jacopobinati/Desktop/HM2/listings_OCT_FINAL.csv")
data_oct.head()
# Out:
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1                NaN                  NaN                 f
# 2                NaN                  NaN                 f
# 3                NaN                  NaN                 f
# 4                NaN                 100%                 t
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        2.0
# 1                  1.0                        1.0
# 2                  1.0                        1.0
# 3                  1.0                        2.0
# 4                  1.0                        1.0
#
#                  host_verifications host_has_profile_pic  \
# 0                ['email', 'phone']                    t
# 1                ['email', 'phone']                    t
# 2                ['email', 'phone']                    t
# 3  ['email', 'phone', 'work_email']                    t
# 4                ['email', 'phone']                    t
#
#   host_identity_verified neighbourhood_cleansed neighbourhood_group_cleansed  \
# 0                      f               Bushwick                     Brooklyn
# 1                      t         Hell's Kitchen                    Manhattan
# 2                      f              Sunnyside                       Queens
# 3                      t     Bedford-Stuyvesant                     Brooklyn
# 4                      t     Bedford-Stuyvesant                     Brooklyn
#
#    ...  review_scores_value  calculated_host_listings_count  \
# 0  ...                 5.00                               1
# 1  ...                  NaN                               1
# 2  ...                  NaN                               1
# 3  ...                 5.00                               1
# 4  ...                 4.92                               1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           1
# 3                                           1
# 4                                           1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             0
#
#   calculated_host_listings_count_shared_rooms  reviews_per_month  ln_price  \
# 0                                           0               0.06  4.174387
# 1                                           0                NaN  4.700480
# 2                                           0                NaN  4.595120
# 3                                           0               0.03  4.248495
# 4                                           0               1.26  5.135798
#
#    property_House  property_Private room  property_Shared Room
# 0           False                   True                 False
# 1           False                   True                 False
# 2            True                  False                 False
# 3            True                  False                 False
# 4            True                  False                 False
#
# [5 rows x 46 columns]

# %%
#Drop columns that are not needed

columns_to_drop = ['host_verifications', 'latitude', 'longitude', 'neighbourhood_group_cleansed', 'host_listings_count',
                   'host_total_listings_count', 'maximum_nights_avg_ntm', 'minimum_minimum_nights', 'calendar_last_scraped',
                   'first_review']

data_oct.drop(columns_to_drop, axis=1, inplace=True)

# %%
# Keep obs with 2 < accommodates < 6, and property_House = 1 only

data_oct = data_oct[(data_oct['accommodates'] >= 2) & (data_oct['accommodates'] <= 6) & (data_oct['property_House'] == 1)]

# %%
# Formatting columns    
for binary in [
    "host_is_superhost",
    "host_has_profile_pic",
    "host_identity_verified",
    "has_availability",
]:
    data_oct[binary] = data_oct[binary].map({"t": True, "f": False})

data_oct["f_property_type"] = data_oct["property_type"].astype("category")
data_oct["f_neighbourhood_cleansed"] = data_oct["neighbourhood_cleansed"].astype("category")
data_oct['n_bathroom'] = data_oct['bathrooms_text'].str.extract('(\d+\.?\d*)').astype(float)
data_oct['host_acceptance_rate'] = data_oct['host_acceptance_rate'].str.replace('%', '').astype(float)
data_oct['host_response_rate'] = data_oct['host_response_rate'].str.replace('%', '').astype(float)

# %%
# add new numeric columns from certain columns

numericals = [
    "accommodates",
    "availability_365",
    "review_scores_value",
    "number_of_reviews_ltm",
    "number_of_reviews_l30d",
    "review_scores_location",
    "review_scores_communication",
    "review_scores_checkin",
    "review_scores_cleanliness",
    "reviews_per_month",
    "minimum_nights",
    "maximum_nights",
    "beds",
    #"bedrooms",
    "host_acceptance_rate",
    "host_response_rate",
]

for col in numericals:
    data_oct["n_" + col] = pd.to_numeric(data_oct[col], errors="coerce")

# %%
#Assign mean values to missing ones

data_oct["n_review_scores_value"].fillna(data_oct["n_review_scores_value"].mean(), inplace=True)
data_oct["n_review_scores_location"].fillna(data_oct["n_review_scores_location"].mean(), inplace=True)
data_oct["n_review_scores_communication"].fillna(data_oct["n_review_scores_communication"].mean(), inplace=True)
data_oct["n_review_scores_checkin"].fillna(data_oct["n_review_scores_checkin"].mean(), inplace=True)
data_oct["n_reviews_per_month"].fillna(data_oct["n_reviews_per_month"].mean(), inplace=True)
#data_oct["n_bedrooms"].fillna(data_oct["n_bedrooms"].mean(), inplace=True)
data_oct["n_host_acceptance_rate"].fillna(data_oct["n_host_acceptance_rate"].mean(), inplace=True)
data_oct["n_host_response_rate"].fillna(data_oct["n_host_response_rate"].mean(), inplace=True)

data_oct = data_oct.assign(
    flag_review_scores_value=np.multiply(data_oct.n_review_scores_value.isna(), 1),
    n_review_scores_value=data_oct.n_review_scores_value.fillna(
        np.mean(data_oct.n_review_scores_value.dropna())
    ),
    flag_review_scores_location=np.multiply(data_oct.n_review_scores_location.isna(), 1),
    n_review_scores_location=data_oct.n_review_scores_location.fillna(
        np.mean(data_oct.n_review_scores_location.dropna())
    ),

    flag_review_scores_communication=np.multiply(data_oct.n_review_scores_communication.isna(), 1),
    n_review_scores_communication=data_oct.n_review_scores_communication.fillna(
        np.mean(data_oct.n_review_scores_communication.dropna())
    ),

    flag_review_scores_checkin=np.multiply(data_oct.n_review_scores_checkin.isna(), 1),
    n_review_scores_checkin=data_oct.n_review_scores_checkin.fillna(
        np.mean(data_oct.n_review_scores_checkin.dropna())
    ),

    flag_reviews_per_month=np.multiply(data_oct.n_reviews_per_month.isna(), 1),
    n_reviews_per_month=data_oct.n_reviews_per_month.fillna(
        np.mean(data_oct.n_reviews_per_month.dropna())
    ),

    flag_review_scores_cleanliness=np.multiply(data_oct.n_review_scores_cleanliness.isna(), 1),
    n_review_scores_cleanliness=data_oct.n_review_scores_cleanliness.fillna(
        np.mean(data_oct.n_review_scores_cleanliness.dropna())
    ),

    flag_host_acceptance_rate=np.multiply(data_oct.host_acceptance_rate.isna(), 1),
    n_host_acceptance_rate=data_oct.host_acceptance_rate.fillna(
        np.mean(data_oct.host_acceptance_rate.dropna())
    ),
    flag_host_response_rate=np.multiply(data_oct.host_response_rate.isna(), 1),
    n_host_response_rate=data_oct.host_response_rate.fillna(
        np.mean(data_oct.host_response_rate.dropna())
    )

)

# %%
 '''
    flag_bedrooms=np.multiply(data_oct.n_bedrooms.isna(), 1),
    n_bedrooms=data_oct.n_bedrooms.fillna(
        np.mean(data_oct.n_bedrooms.dropna())
    ),'''
# Out:
# '\n   flag_bedrooms=np.multiply(data_oct.n_bedrooms.isna(), 1),\n   n_bedrooms=data_oct.n_bedrooms.fillna(\n       np.mean(data_oct.n_bedrooms.dropna())\n   ),'

# %%
columns_to_check = ['n_bathroom', 'n_beds', 'host_has_profile_pic', 'host_is_superhost', 'host_identity_verified']
data_oct.dropna(subset=columns_to_check, inplace=True)

# %%
# Remove various strings, split amenities and turn into dtype:object

replace_str_dict = {
    '"' : "",
    ", " : ",",
    "\\\\" : "",
    ":" : "",
    "\\+" : "_",
}

data_oct["amenities"] = data_oct["amenities"].replace(replace_str_dict, regex=True).str.strip("[]").str.split(",")

# %%
# Function to merge amenities containing any keyword from a dictionary (case-insensitive)
def merge_items_with_keywords(amenities_list, merge_dict):
    merged_amenities = []
    for amenities in amenities_list:
        merged_item = []
        for amenity in amenities:
            lower_amenity = amenity.lower()
            for new_category, old_categories in merge_dict.items():
                if any(old_category in lower_amenity for old_category in old_categories):
                    merged_item.append(new_category)
                    break
            else:
                merged_item.append(amenity)
        merged_amenities.append(list(set(merged_item)))
    return merged_amenities

# %%
# Dictionary to merge amenities

merge_dict = {
    'wifi': ['wifi'],
    'kitchen': ['kitchen', 'kitchenette'],
    'stove': ['stove'],
    'oven': ['oven'],
    'microwave': ['microwave'],
    'refrigerator': ['refrigerator', 'fridge'],
    'dishwasher': ['dishwasher'],
    'kettel': ['kettle'],
    'toaster': ['toaster'],
    'coffee': ['coffee maker', 'machine', 'coffee', 'espresso', 'nespresso'],
    'tv': ['tv'],
    'sound_system': ['speaker', 'sound'],
    'game_console': ['game console', 'ps2', 'ps3', 'ps4', 'ps5', 
                     'playstation', 'wii', 'xbox'],
    'baby': ['baby', 'toys'],
    'body_wash': ['body', 'soap', 'shower gel'],
    'shampoo': ['shampoo'],
    'conditioner': ['conditioner'],
    'hair dryer': ['hair dryer'],
    'laundry': ['washer', 'laundry'],
    'backyard': ['backyard'],
    'grill': ['grill'],
    'breakfast': ['breakfast'],
    'clothing_storage': ['clothing storage'],
    'ac': ['ac - split type ductless system', 'air conditioning', 'central air conditioning', 'window ac unit'],
    'heating': ['heating']
}

# %%
# Merge some amenities together

data_oct['amenities'] = merge_items_with_keywords(data_oct['amenities'], merge_dict)

# %%
# Generate dummies by amenities

dummies = data_oct['amenities'].str.join('|').str.get_dummies()
dummies.columns = "d_" + dummies.columns.str.replace('/', '_').str.replace(' ', '_').str.replace('-', '_').str.replace('\\\\', '')

# %%
dummies.head()
# Out:
#     d_000_BTU_in_the_Bedroom_and_12  d_2_5_years_old  d_5_10_years_old  d_9  \
# 3                                 0                0                 0    0
# 4                                 0                0                 0    0
# 8                                 0                0                 0    0
# 9                                 0                0                 0    0
# 14                                0                0                 0    0
#
#     d_Amazon_Prime_Video  d_Avanti  d_Baking_sheet  d_Barbecue_utensils  \
# 3                      0         0               0                    0
# 4                      0         0               1                    0
# 8                      0         0               0                    0
# 9                      0         0               1                    0
# 14                     0         0               0                    0
#
#     d_Bathtub  d_Bay_view  ...  d_stationary_bike  d_stove  d_tesla_only  \
# 3           0           0  ...                  0        0             0
# 4           0           0  ...                  0        1             0
# 8           0           0  ...                  0        0             0
# 9           1           0  ...                  0        1             0
# 14          0           0  ...                  0        0             0
#
#     d_toaster  d_treadmill  d_tv  d_wardrobe  d_wifi  d_wood_burning  \
# 3           0            0     0           0       1               0
# 4           1            0     1           0       1               0
# 8           0            0     0           0       1               0
# 9           0            0     0           0       1               0
# 14          0            0     1           0       1               0
#
#     d_yoga_mat
# 3            0
# 4            0
# 8            0
# 9            0
# 14           0
#
# [5 rows x 357 columns]

# %%
# Top amenities in NYC
top_150_columns = dummies.sum().sort_values(ascending=False).head(150).index
final_dummies = dummies[top_150_columns]

# %%
final_dummies.head()
# Out:
#     d_wifi  d_kitchen  d_ac  d_Smoke_alarm  d_heating  d_tv  d_Essentials  \
# 3        1          1     1              1          1     0             1
# 4        1          1     1              1          1     1             1
# 8        1          1     1              1          1     0             1
# 9        1          1     1              0          1     0             1
# 14       1          0     1              1          1     1             1
#
#     d_Carbon_monoxide_alarm  d_Hangers  d_hair_dryer  ...  d_Beach_access  \
# 3                         1          1             1  ...               0
# 4                         1          1             1  ...               0
# 8                         0          0             0  ...               0
# 9                         0          1             1  ...               0
# 14                        0          0             1  ...               0
#
#     d_Exercise_equipment_yoga_mat  d_Paid_parking_lot_off_premises  \
# 3                               0                                0
# 4                               0                                0
# 8                               0                                0
# 9                               0                                0
# 14                              0                                0
#
#     d_Bread_maker  d_EV_charger  d_stationary_bike  \
# 3               0             0                  0
# 4               0             0                  0
# 8               0             0                  0
# 9               0             0                  0
# 14              0             0                  0
#
#     d_Pack_u2019n_play_Travel_crib___always_at_the_listing  \
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
#     d_Table_corner_guards  d_Bay_view  \
# 3                       0           0
# 4                       0           0
# 8                       0           0
# 9                       0           0
# 14                      0           0
#
#     d_Free_driveway_parking_on_premises_u2013_1_space
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
# [5 rows x 150 columns]

# %%
#Add dummies amneties to data_oct
data_oct = pd.concat([data_oct, final_dummies], axis=1)

# %%
data_oct.head()
# Out:
#     host_response_rate  host_acceptance_rate host_is_superhost  \
# 3                  NaN                   NaN             False
# 4                  NaN                 100.0              True
# 8                  NaN                   NaN             False
# 9                  NaN                   0.0             False
# 14               100.0                  99.0             False
#
#    host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 3                  True                   True     Bedford-Stuyvesant
# 4                  True                   True     Bedford-Stuyvesant
# 8                  True                   True               Kips Bay
# 9                  True                  False          Crown Heights
# 14                 True                   True           Williamsburg
#
#    property_type  accommodates bathrooms_text  beds  ... d_Beach_access  \
# 3          House             2         1 bath   1.0  ...              0
# 4          House             4         1 bath   2.0  ...              0
# 8          House             2         1 bath   1.0  ...              0
# 9          House             2         1 bath   2.0  ...              0
# 14         House             2         1 bath   1.0  ...              0
#
#     d_Exercise_equipment_yoga_mat  d_Paid_parking_lot_off_premises  \
# 3                               0                                0
# 4                               0                                0
# 8                               0                                0
# 9                               0                                0
# 14                              0                                0
#
#     d_Bread_maker  d_EV_charger  d_stationary_bike  \
# 3               0             0                  0
# 4               0             0                  0
# 8               0             0                  0
# 9               0             0                  0
# 14              0             0                  0
#
#     d_Pack_u2019n_play_Travel_crib___always_at_the_listing  \
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
#     d_Table_corner_guards  d_Bay_view  \
# 3                       0           0
# 4                       0           0
# 8                       0           0
# 9                       0           0
# 14                      0           0
#
#     d_Free_driveway_parking_on_premises_u2013_1_space
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
# [5 rows x 212 columns]

# %%
# Basic Variables inc neighnourhood
basic_vars = [
    "n_accommodates",
    #"n_bedrooms",
    "n_bathroom",
    "n_beds",
    "f_neighbourhood_cleansed",
    "n_availability_365",
    "n_minimum_nights",
    "n_maximum_nights",
    "host_is_superhost",
    "n_host_acceptance_rate",
    "host_has_profile_pic",
    "n_host_response_rate",
]

# reviews
reviews = [
    "n_review_scores_value",
    "flag_review_scores_value",
    "n_review_scores_location",
    "flag_review_scores_location",
    "n_review_scores_communication",
    "flag_review_scores_communication",
    "n_review_scores_checkin",
    "flag_review_scores_checkin",
    "n_review_scores_cleanliness",
    "flag_review_scores_cleanliness",
    "n_reviews_per_month",
    "flag_reviews_per_month"
]

# Dummy variables
amenities = [col for col in data_oct if col.startswith("d_")]

# interactions for the LASSO
# from ch14
X1 = [
    "n_accommodates:d_wifi",
    "d_breakfast:d_kitchen",
    "d_heating:n_accommodates",
    #"d_ac:n_bedrooms",
    "n_minimum_nights:n_accommodates",
    "n_availability_365:minimum_nights",
    "n_review_scores_value:n_reviews_per_month",
    "n_host_acceptance_rate:n_host_response_rate",
    "host_identity_verified:host_is_superhost",
]
# with neighbourhood
X2 = [
    "n_availability_365:f_neighbourhood_cleansed",
    "n_accommodates:f_neighbourhood_cleansed",
    "d_wifi:f_neighbourhood_cleansed",
    "d_Smoke_alarm:f_neighbourhood_cleansed",
]

# %%
predictors_1 = basic_vars
predictors_2 = basic_vars + reviews + amenities
predictors_3 = basic_vars + reviews + amenities + X1 + X2

# %%
amenities
# Out:
# ['d_wifi',
#  'd_kitchen',
#  'd_ac',
#  'd_Smoke_alarm',
#  'd_heating',
#  'd_tv',
#  'd_Essentials',
#  'd_Carbon_monoxide_alarm',
#  'd_Hangers',
#  'd_hair_dryer',
#  'd_Iron',
#  'd_Hot_water',
#  'd_refrigerator',
#  'd_shampoo',
#  'd_Dishes_and_silverware',
#  'd_Cooking_basics',
#  'd_coffee',
#  'd_Bed_linens',
#  'd_microwave',
#  'd_oven',
#  'd_stove',
#  'd_laundry',
#  'd_Dedicated_workspace',
#  'd_Self_check_in',
#  'd_Fire_extinguisher',
#  'd_Long_term_stays_allowed',
#  'd_Free_street_parking',
#  'd_Extra_pillows_and_blankets',
#  'd_First_aid_kit',
#  'd_Bathtub',
#  'd_body_wash',
#  'd_Cleaning_products',
#  'd_clothing_storage',
#  'd_Private_entrance',
#  'd_Freezer',
#  'd_dishwasher',
#  'd_Pets_allowed',
#  'd_Dining_table',
#  'd_Elevator',
#  'd_kettel',
#  'd_Wine_glasses',
#  'd_Dryer',
#  'd_Lockbox',
#  'd_toaster',
#  'd_conditioner',
#  'd_Laundromat_nearby',
#  'd_Room_darkening_shades',
#  'd_Security_cameras_on_property',
#  'd_Luggage_dropoff_allowed',
#  'd_Baking_sheet',
#  'd_backyard',
#  'd_Blender',
#  'd_Books_and_reading_material',
#  'd_Free_parking_on_premises',
#  'd_Outdoor_furniture',
#  'd_Gym',
#  'd_Outdoor_dining_area',
#  'd_Host_greets_you',
#  'd_Ethernet_connection',
#  'd_Portable_fans',
#  'd_grill',
#  'd_Free_dryer_u2013_In_unit',
#  'd_Keypad',
#  'd_Private_patio_or_balcony',
#  'd_Paid_parking_off_premises',
#  'd_Netflix',
#  'd_baby',
#  'd_Cleaning_available_during_stay',
#  'd_Single_level_home',
#  'd_Ceiling_fan',
#  'd_sound_system',
#  'd_Building_staff',
#  'd_City_skyline_view',
#  'd_Window_guards',
#  'd_Board_games',
#  'd_Smart_lock',
#  'd_Patio_or_balcony',
#  'd_Exercise_equipment',
#  'd_Paid_dryer_u2013_In_building',
#  'd_Drying_rack_for_clothing',
#  'd_Paid_parking_on_premises',
#  'd_Pack_u2019n_play_Travel_crib',
#  'd_Hulu',
#  'd_Crib',
#  'd_Paid_parking_garage_off_premises',
#  'd_Safe',
#  'd_HBO_Max',
#  'd_Rice_maker',
#  'd_Indoor_fireplace',
#  'd_Childrenu2019s_dinnerware',
#  'd_breakfast',
#  'd_Barbecue_utensils',
#  'd_High_chair',
#  'd_Garden_view',
#  'd_Disney_',
#  'd_Trash_compactor',
#  'd_Amazon_Prime_Video',
#  'd_Roku',
#  'd_Smoking_allowed',
#  'd_Mosquito_net',
#  'd_Shared_gym_in_building',
#  'd_Pool',
#  'd_Shared_patio_or_balcony',
#  'd_Bidet',
#  'd_Fire_pit',
#  'd_Outlet_covers',
#  'd_Hot_tub',
#  'd_Dryer_u2013_In_building',
#  'd_Courtyard_view',
#  'd_Dryer_u2013u00a0In_unit',
#  'd_standard_cable',
#  'd_and_dresser',
#  'd_game_console',
#  'd_Portable_heater',
#  'd_Free_dryer_u2013_In_building',
#  'd_Paid_street_parking_off_premises',
#  'd_Record_player',
#  'd_Piano',
#  'd_yoga_mat',
#  'd_Exercise_equipment_free_weights',
#  'd_Pack_u2019n_play_Travel_crib___available_upon_request',
#  'd_Pool_table',
#  'd_Crib___available_upon_request',
#  'd_Waterfront',
#  'd_wardrobe',
#  'd_Park_view',
#  'd_premium_cable',
#  'd_closet',
#  'd_River_view',
#  'd_Sun_loungers',
#  'd_Hammock',
#  'd_Bikes',
#  'd_french_press',
#  'd_Chromecast',
#  'd_Indoor_fireplace_electric',
#  'd_Changing_table',
#  'd_Beach_essentials',
#  'd_Public_or_shared_beach_access',
#  'd_Fireplace_guards',
#  'd_Private_hot_tub',
#  'd_Beach_access',
#  'd_Exercise_equipment_yoga_mat',
#  'd_Paid_parking_lot_off_premises',
#  'd_Bread_maker',
#  'd_EV_charger',
#  'd_stationary_bike',
#  'd_Pack_u2019n_play_Travel_crib___always_at_the_listing',
#  'd_Table_corner_guards',
#  'd_Bay_view',
#  'd_Free_driveway_parking_on_premises_u2013_1_space']

# %%
#data_oct.to_csv('/Users/Admin/Desktop/listings_APR_FINAL2.csv', index=False)

# %%
#Split the data
data_train, data_holdout = train_test_split(data_oct, train_size=0.8, random_state=42)

# %%
data_oct.head()
# Out:
#     host_response_rate  host_acceptance_rate host_is_superhost  \
# 3                  NaN                   NaN             False
# 4                  NaN                 100.0              True
# 8                  NaN                   NaN             False
# 9                  NaN                   0.0             False
# 14               100.0                  99.0             False
#
#    host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 3                  True                   True     Bedford-Stuyvesant
# 4                  True                   True     Bedford-Stuyvesant
# 8                  True                   True               Kips Bay
# 9                  True                  False          Crown Heights
# 14                 True                   True           Williamsburg
#
#    property_type  accommodates bathrooms_text  beds  ... d_Beach_access  \
# 3          House             2         1 bath   1.0  ...              0
# 4          House             4         1 bath   2.0  ...              0
# 8          House             2         1 bath   1.0  ...              0
# 9          House             2         1 bath   2.0  ...              0
# 14         House             2         1 bath   1.0  ...              0
#
#     d_Exercise_equipment_yoga_mat  d_Paid_parking_lot_off_premises  \
# 3                               0                                0
# 4                               0                                0
# 8                               0                                0
# 9                               0                                0
# 14                              0                                0
#
#     d_Bread_maker  d_EV_charger  d_stationary_bike  \
# 3               0             0                  0
# 4               0             0                  0
# 8               0             0                  0
# 9               0             0                  0
# 14              0             0                  0
#
#     d_Pack_u2019n_play_Travel_crib___always_at_the_listing  \
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
#     d_Table_corner_guards  d_Bay_view  \
# 3                       0           0
# 4                       0           0
# 8                       0           0
# 9                       0           0
# 14                      0           0
#
#     d_Free_driveway_parking_on_premises_u2013_1_space
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
# [5 rows x 212 columns]

# %% [markdown]
# # Random Forest

# %%
ncores = 3

# %%
rfr = RandomForestRegressor(
    random_state=42,
    criterion="squared_error",
    n_estimators=30,
    oob_score=True,
    n_jobs=-1,
)

tune_grid = {
    "max_features": [10, 12, 14],
    "min_samples_split": [6, 11, 16],
}

rf_random = GridSearchCV(
    rfr,
    tune_grid,
    cv=5,
    scoring="neg_root_mean_squared_error",
    verbose=3,
)

y, X = dmatrices("price ~ " + " + ".join(predictors_2), data_train)

rf_model_2 = rf_random.fit(X, y.ravel())
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_features=10, min_samples_split=6;, score=-173.828 total time=   0.4s
# [CV 2/5] END max_features=10, min_samples_split=6;, score=-345.426 total time=   0.4s
# [CV 3/5] END max_features=10, min_samples_split=6;, score=-262.763 total time=   0.4s
# [CV 4/5] END max_features=10, min_samples_split=6;, score=-294.544 total time=   0.3s
# [CV 5/5] END max_features=10, min_samples_split=6;, score=-214.031 total time=   0.3s
# [CV 1/5] END max_features=10, min_samples_split=11;, score=-175.657 total time=   0.3s
# [CV 2/5] END max_features=10, min_samples_split=11;, score=-345.881 total time=   0.3s
# [CV 3/5] END max_features=10, min_samples_split=11;, score=-262.907 total time=   0.3s
# [CV 4/5] END max_features=10, min_samples_split=11;, score=-294.531 total time=   0.3s
# [CV 5/5] END max_features=10, min_samples_split=11;, score=-214.375 total time=   0.3s
# [CV 1/5] END max_features=10, min_samples_split=16;, score=-177.205 total time=   0.3s
# [CV 2/5] END max_features=10, min_samples_split=16;, score=-344.925 total time=   0.3s
# [CV 3/5] END max_features=10, min_samples_split=16;, score=-264.939 total time=   0.2s
# [CV 4/5] END max_features=10, min_samples_split=16;, score=-294.833 total time=   0.2s
# [CV 5/5] END max_features=10, min_samples_split=16;, score=-214.692 total time=   0.2s
# [CV 1/5] END max_features=12, min_samples_split=6;, score=-175.075 total time=   0.3s
# [CV 2/5] END max_features=12, min_samples_split=6;, score=-343.862 total time=   0.3s
# [CV 3/5] END max_features=12, min_samples_split=6;, score=-263.977 total time=   0.3s
# [CV 4/5] END max_features=12, min_samples_split=6;, score=-294.350 total time=   0.3s
# [CV 5/5] END max_features=12, min_samples_split=6;, score=-215.520 total time=   0.3s
# [CV 1/5] END max_features=12, min_samples_split=11;, score=-176.187 total time=   0.3s
# [CV 2/5] END max_features=12, min_samples_split=11;, score=-345.830 total time=   0.3s
# [CV 3/5] END max_features=12, min_samples_split=11;, score=-262.266 total time=   0.3s
# [CV 4/5] END max_features=12, min_samples_split=11;, score=-292.442 total time=   0.3s
# [CV 5/5] END max_features=12, min_samples_split=11;, score=-214.496 total time=   0.3s
# [CV 1/5] END max_features=12, min_samples_split=16;, score=-173.800 total time=   0.4s
# [CV 2/5] END max_features=12, min_samples_split=16;, score=-344.215 total time=   0.3s
# [CV 3/5] END max_features=12, min_samples_split=16;, score=-264.148 total time=   0.3s
# [CV 4/5] END max_features=12, min_samples_split=16;, score=-293.257 total time=   0.3s
# [CV 5/5] END max_features=12, min_samples_split=16;, score=-214.107 total time=   0.2s
# [CV 1/5] END max_features=14, min_samples_split=6;, score=-176.964 total time=   0.4s
# [CV 2/5] END max_features=14, min_samples_split=6;, score=-344.567 total time=   0.3s
# [CV 3/5] END max_features=14, min_samples_split=6;, score=-262.041 total time=   0.3s
# [CV 4/5] END max_features=14, min_samples_split=6;, score=-293.235 total time=   0.4s
# [CV 5/5] END max_features=14, min_samples_split=6;, score=-213.888 total time=   0.4s
# [CV 1/5] END max_features=14, min_samples_split=11;, score=-173.904 total time=   0.3s
# [CV 2/5] END max_features=14, min_samples_split=11;, score=-344.661 total time=   0.3s
# [CV 3/5] END max_features=14, min_samples_split=11;, score=-264.458 total time=   0.3s
# [CV 4/5] END max_features=14, min_samples_split=11;, score=-293.678 total time=   0.4s
# [CV 5/5] END max_features=14, min_samples_split=11;, score=-213.998 total time=   0.4s
# [CV 1/5] END max_features=14, min_samples_split=16;, score=-173.746 total time=   0.3s
# [CV 2/5] END max_features=14, min_samples_split=16;, score=-344.731 total time=   0.3s
# [CV 3/5] END max_features=14, min_samples_split=16;, score=-263.702 total time=   0.3s
# [CV 4/5] END max_features=14, min_samples_split=16;, score=-293.841 total time=   0.3s
# [CV 5/5] END max_features=14, min_samples_split=16;, score=-212.287 total time=   0.3s

# %%
rfr = RandomForestRegressor(
    random_state=42,
    criterion="squared_error",
    n_estimators=30,
    oob_score=True,
    n_jobs=-1,
)

tune_grid = {
    "max_features": [10, 12, 14],
    "min_samples_split": [6, 11, 16],
}

rf_random = GridSearchCV(
    rfr,
    tune_grid,
    cv=5,
    scoring="neg_root_mean_squared_error",
    verbose=3,
)

y, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)

rf_model_3 = rf_random.fit(X, y.ravel())
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_features=10, min_samples_split=6;, score=-175.937 total time=   0.6s
# [CV 2/5] END max_features=10, min_samples_split=6;, score=-344.041 total time=   0.6s
# [CV 3/5] END max_features=10, min_samples_split=6;, score=-264.327 total time=   0.6s
# [CV 4/5] END max_features=10, min_samples_split=6;, score=-294.062 total time=   0.6s
# [CV 5/5] END max_features=10, min_samples_split=6;, score=-214.594 total time=   0.7s
# [CV 1/5] END max_features=10, min_samples_split=11;, score=-177.017 total time=   0.8s
# [CV 2/5] END max_features=10, min_samples_split=11;, score=-345.765 total time=   0.7s
# [CV 3/5] END max_features=10, min_samples_split=11;, score=-265.155 total time=   0.7s
# [CV 4/5] END max_features=10, min_samples_split=11;, score=-294.481 total time=   0.6s
# [CV 5/5] END max_features=10, min_samples_split=11;, score=-215.216 total time=   0.5s
# [CV 1/5] END max_features=10, min_samples_split=16;, score=-176.215 total time=   0.5s
# [CV 2/5] END max_features=10, min_samples_split=16;, score=-344.415 total time=   0.5s
# [CV 3/5] END max_features=10, min_samples_split=16;, score=-265.729 total time=   0.5s
# [CV 4/5] END max_features=10, min_samples_split=16;, score=-292.890 total time=   0.6s
# [CV 5/5] END max_features=10, min_samples_split=16;, score=-214.373 total time=   0.5s
# [CV 1/5] END max_features=12, min_samples_split=6;, score=-174.007 total time=   0.6s
# [CV 2/5] END max_features=12, min_samples_split=6;, score=-345.502 total time=   0.6s
# [CV 3/5] END max_features=12, min_samples_split=6;, score=-262.158 total time=   0.7s
# [CV 4/5] END max_features=12, min_samples_split=6;, score=-293.083 total time=   0.7s
# [CV 5/5] END max_features=12, min_samples_split=6;, score=-214.597 total time=   0.6s
# [CV 1/5] END max_features=12, min_samples_split=11;, score=-176.050 total time=   0.6s
# [CV 2/5] END max_features=12, min_samples_split=11;, score=-345.021 total time=   0.5s
# [CV 3/5] END max_features=12, min_samples_split=11;, score=-266.784 total time=   0.6s
# [CV 4/5] END max_features=12, min_samples_split=11;, score=-292.408 total time=   0.5s
# [CV 5/5] END max_features=12, min_samples_split=11;, score=-213.365 total time=   0.6s
# [CV 1/5] END max_features=12, min_samples_split=16;, score=-175.368 total time=   0.6s
# [CV 2/5] END max_features=12, min_samples_split=16;, score=-345.148 total time=   0.6s
# [CV 3/5] END max_features=12, min_samples_split=16;, score=-264.880 total time=   0.6s
# [CV 4/5] END max_features=12, min_samples_split=16;, score=-293.523 total time=   0.6s
# [CV 5/5] END max_features=12, min_samples_split=16;, score=-214.573 total time=   0.6s
# [CV 1/5] END max_features=14, min_samples_split=6;, score=-175.664 total time=   0.8s
# [CV 2/5] END max_features=14, min_samples_split=6;, score=-343.764 total time=   0.8s
# [CV 3/5] END max_features=14, min_samples_split=6;, score=-265.298 total time=   3.0s
# [CV 4/5] END max_features=14, min_samples_split=6;, score=-293.283 total time=   0.9s
# [CV 5/5] END max_features=14, min_samples_split=6;, score=-212.689 total time=   0.7s
# [CV 1/5] END max_features=14, min_samples_split=11;, score=-176.193 total time=   0.6s
# [CV 2/5] END max_features=14, min_samples_split=11;, score=-343.487 total time=   0.6s
# [CV 3/5] END max_features=14, min_samples_split=11;, score=-264.757 total time=   0.6s
# [CV 4/5] END max_features=14, min_samples_split=11;, score=-293.281 total time=   0.7s
# [CV 5/5] END max_features=14, min_samples_split=11;, score=-212.784 total time=   0.6s
# [CV 1/5] END max_features=14, min_samples_split=16;, score=-174.207 total time=   0.6s
# [CV 2/5] END max_features=14, min_samples_split=16;, score=-344.039 total time=   0.6s
# [CV 3/5] END max_features=14, min_samples_split=16;, score=-266.112 total time=   0.7s
# [CV 4/5] END max_features=14, min_samples_split=16;, score=-293.611 total time=   0.7s
# [CV 5/5] END max_features=14, min_samples_split=16;, score=-215.129 total time=   0.7s

# %%
pd.DataFrame(rf_model_2.cv_results_)[
    ["param_max_features", "param_min_samples_split", "mean_test_score"]
].assign(
    mean_test_score=lambda x: x["mean_test_score"] * -1,
    Variables=lambda x: x["param_max_features"],
    Min_nodes=lambda x: x["param_min_samples_split"] - 1,
).pivot(
    index="Min_nodes", columns="Variables", values="mean_test_score"
).round(
    2
)
# Out:
# Variables      10      12      14
# Min_nodes
# 5          258.12  258.56  258.14
# 10         258.67  258.24  258.14
# 15         259.32  257.91  257.66

# %%
pd.DataFrame(rf_model_3.cv_results_)[
    ["param_max_features", "param_min_samples_split", "mean_test_score"]
].assign(
    mean_test_score=lambda x: x["mean_test_score"] * -1,
    Variables=lambda x: x["param_max_features"],
    Min_nodes=lambda x: x["param_min_samples_split"] - 1,
).pivot(
    index="Min_nodes", columns="Variables", values="mean_test_score"
).round(
    2
)
# Out:
# Variables      10      12      14
# Min_nodes
# 5          258.59  257.87  258.14
# 10         259.53  258.73  258.10
# 15         258.72  258.70  258.62

# %%
pd.DataFrame(
    {
        "Min vars": [
            rf_model_2.best_estimator_.max_features,
            rf_model_3.best_estimator_.max_features,
        ],
        "Min nodes": [
            rf_model_2.best_estimator_.min_samples_split - 1,
            rf_model_3.best_estimator_.min_samples_split - 1,
        ],
    },
    ["RF 2", "RF 3"],
)
# Out:
#       Min vars  Min nodes
# RF 2        14         15
# RF 3        12          5

# %%
pd.DataFrame(
    {
        "RMSE": [
            rf_model_2.cv_results_["mean_test_score"].min(),
            rf_model_3.cv_results_["mean_test_score"].min(),
        ]
    },
    ["RF B", "RF C"],
).round(2) * -1
# Out:
#         RMSE
# RF B  259.32
# RF C  259.53

# %% [markdown]
# # OLS

# %%
data_oct.head()
# Out:
#     host_response_rate  host_acceptance_rate host_is_superhost  \
# 3                  NaN                   NaN             False
# 4                  NaN                 100.0              True
# 8                  NaN                   NaN             False
# 9                  NaN                   0.0             False
# 14               100.0                  99.0             False
#
#    host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 3                  True                   True     Bedford-Stuyvesant
# 4                  True                   True     Bedford-Stuyvesant
# 8                  True                   True               Kips Bay
# 9                  True                  False          Crown Heights
# 14                 True                   True           Williamsburg
#
#    property_type  accommodates bathrooms_text  beds  ... d_Beach_access  \
# 3          House             2         1 bath   1.0  ...              0
# 4          House             4         1 bath   2.0  ...              0
# 8          House             2         1 bath   1.0  ...              0
# 9          House             2         1 bath   2.0  ...              0
# 14         House             2         1 bath   1.0  ...              0
#
#     d_Exercise_equipment_yoga_mat  d_Paid_parking_lot_off_premises  \
# 3                               0                                0
# 4                               0                                0
# 8                               0                                0
# 9                               0                                0
# 14                              0                                0
#
#     d_Bread_maker  d_EV_charger  d_stationary_bike  \
# 3               0             0                  0
# 4               0             0                  0
# 8               0             0                  0
# 9               0             0                  0
# 14              0             0                  0
#
#     d_Pack_u2019n_play_Travel_crib___always_at_the_listing  \
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
#     d_Table_corner_guards  d_Bay_view  \
# 3                       0           0
# 4                       0           0
# 8                       0           0
# 9                       0           0
# 14                      0           0
#
#     d_Free_driveway_parking_on_premises_u2013_1_space
# 3                                                   0
# 4                                                   0
# 8                                                   0
# 9                                                   0
# 14                                                  0
#
# [5 rows x 212 columns]

# %%
#print(data_oct[basic_vars].dtypes)
print(data_oct[reviews].dtypes)
# Out:
# n_review_scores_value               float64
# flag_review_scores_value              int32
# n_review_scores_location            float64
# flag_review_scores_location           int32
# n_review_scores_communication       float64
# flag_review_scores_communication      int32
# n_review_scores_checkin             float64
# flag_review_scores_checkin            int32
# n_review_scores_cleanliness         float64
# flag_review_scores_cleanliness        int32
# n_reviews_per_month                 float64
# flag_reviews_per_month                int32
# dtype: object

# %%
'''
y, X = dmatrices("price ~ " + " + ".join(predictors_1), data_train)
ols_model1 = LinearRegression().fit(X,y)
y_hat1 = ols_model1.predict(X)
ols_rmse1 = mean_squared_error(y,y_hat1,squared=False)

y_test, X_test = dmatrices("price ~ " + " + ".join(predictors_1), data_holdout)
ols_test1 = LinearRegression().fit(X_test,y_test)
y_hat_test1 = ols_test1.predict(X_test)
ols_cv_rmse1 = mean_squared_error(y_test,y_hat_test1,squared=False)
#-----------------------------------#

y, X = dmatrices("price ~ " + " + ".join(predictors_2), data_train)
ols_model2 = LinearRegression().fit(X,y)
y_hat2 = ols_model2.predict(X)
ols_rmse2 = mean_squared_error(y,y_hat2,squared=False)


y_test, X_test = dmatrices("price ~ " + " + ".join(predictors_2), data_holdout)
ols_test2 = LinearRegression().fit(X_test,y_test)
y_hat_test2 = ols_test2.predict(X_test)
ols_cv_rmse2 = mean_squared_error(y_test,y_hat_test2,squared=False)
#-----------------------------------#

y, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)
ols_model3 = LinearRegression().fit(X,y)
y_hat3 = ols_model3.predict(X)
ols_rmse3 = mean_squared_error(y,y_hat3,squared=False)

y_test, X_test = dmatrices("price ~ " + " + ".join(predictors_3), data_holdout)
ols_test3 = LinearRegression().fit(X_test,y_test)
y_hat_test3 = ols_test3.predict(X_test)
ols_cv_rmse3 = mean_squared_error(y_test,y_hat_test3,squared=False)
'''
# Out:
# '\ny, X = dmatrices("price ~ " + " + ".join(predictors_1), data_train)\nols_model1 = LinearRegression().fit(X,y)\ny_hat1 = ols_model1.predict(X)\nols_rmse1 = mean_squared_error(y,y_hat1,squared=False)\n\ny_test, X_test = dmatrices("price ~ " + " + ".join(predictors_1), data_holdout)\nols_test1 = LinearRegression().fit(X_test,y_test)\ny_hat_test1 = ols_test1.predict(X_test)\nols_cv_rmse1 = mean_squared_error(y_test,y_hat_test1,squared=False)\n#-----------------------------------#\n\ny, X = dmatrices("price ~ " + " + ".join(predictors_2), data_train)\nols_model2 = LinearRegression().fit(X,y)\ny_hat2 = ols_model2.predict(X)\nols_rmse2 = mean_squared_error(y,y_hat2,squared=False)\n\n\ny_test, X_test = dmatrices("price ~ " + " + ".join(predictors_2), data_holdout)\nols_test2 = LinearRegression().fit(X_test,y_test)\ny_hat_test2 = ols_test2.predict(X_test)\nols_cv_rmse2 = mean_squared_error(y_test,y_hat_test2,squared=False)\n#-----------------------------------#\n\ny, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)\nols_model3 = LinearRegression().fit(X,y)\ny_hat3 = ols_model3.predict(X)\nols_rmse3 = mean_squared_error(y,y_hat3,squared=False)\n\ny_test, X_test = dmatrices("price ~ " + " + ".join(predictors_3), data_holdout)\nols_test3 = LinearRegression().fit(X_test,y_test)\ny_hat_test3 = ols_test3.predict(X_test)\nols_cv_rmse3 = mean_squared_error(y_test,y_hat_test3,squared=False)\n'

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
def cross_validate(data, formula, model, kf):
    rmse_values = []
    for train_index, test_index in kf.split(data):
        data_train, data_test = data.iloc[train_index], data.iloc[test_index]

        y_train, X_train = patsy.dmatrices(formula, data_train)
        y_test, X_test = patsy.dmatrices(formula, data_test)

        results = model(y_train, X_train).fit()

        y_pred = results.predict(X_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        rmse_values.append(rmse)

    average_rmse = np.mean(rmse_values)
    return average_rmse

# %%
formulas = [
    ("OLS 1", "price ~ " + " + ".join(predictors_1)),
    ("OLS 2", "price ~ " + " + ".join(predictors_2)),
    ("OLS 3", "price ~ " + " + ".join(predictors_3))
]

rmse_values = []
for model_name, formula in formulas:
    rmse = cross_validate(data_oct, formula, sm.OLS, kf)
    rmse_values.append(rmse)

# %%
rmse_values
# Out:
# [791.7210621249121, 638.7865708395306, 544.5866147232985]

# %%
'''
formulas_ln = [
    ("Ln OLS 1", "ln_price ~ " + " + ".join(predictors_1)),
    ("Ln OLS 2", "ln_price ~ " + " + ".join(predictors_2)),
    ("Ln OLS 3", "ln_price ~ " + " + ".join(predictors_3))
]
'''
# Out:
# '\nformulas_ln = [\n    ("Ln OLS 1", "ln_price ~ " + " + ".join(predictors_1)),\n    ("Ln OLS 2", "ln_price ~ " + " + ".join(predictors_2)),\n    ("Ln OLS 3", "ln_price ~ " + " + ".join(predictors_3))\n]\n'

# %%
'''
ln_rmse_values = []
for model_name, formula in formulas_ln:
    ln_rmse = cross_validate(data_oct, formula, sm.OLS, kf)
    ln_rmse_values.append(ln_rmse)
'''
# Out:
# '\nln_rmse_values = []\nfor model_name, formula in formulas_ln:\n    ln_rmse = cross_validate(data_oct, formula, sm.OLS, kf)\n    ln_rmse_values.append(ln_rmse)\n'

# %%
#ln_rmse_values

# %% [markdown]
# # LASSO

# %%
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
lambdas = np.arange(0.05, 1.01, 0.05)
print(lambdas)
# Out:
# [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7
#  0.75 0.8  0.85 0.9  0.95 1.  ]

# %%
y, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)
X_featnames = X.design_info.column_names
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
lasso_fit = LassoCV(alphas=lambdas, cv=5, random_state=42).fit(X, y)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1563: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13892428.819607615, tolerance: 108758.0115800992
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1388408.9418609142, tolerance: 82237.6844138221
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11766488.925861716, tolerance: 96167.84713680847
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5707213.6842576265, tolerance: 103645.49042871795
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
lasso_fit.alpha_
# Out:
# 1.0

# %%
rmse_lambda_folds = (
    pd.DataFrame(lasso_fit.mse_path_, index=lambdas[::-1])
    .apply(np.sqrt)
    .mean(axis=1)
    .to_frame(name="Test RMSE")
    .round(2)
)

# %%
'''
lasso_model = ElasticNet(l1_ratio=1, fit_intercept=True)

lasso_model_cv = GridSearchCV(
    lasso_model,
    {"alpha": [i / 100 for i in range(1, 26, 1)]},
    cv=5,
    scoring="neg_root_mean_squared_error",
    verbose=3,
    n_jobs=-1,
)

y, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)
y, X = np.array(y), np.array(X)

lasso_model_cv.fit(X, y.ravel())

lasso_rmse = (
    pd.DataFrame(lasso_model_cv.cv_results_)
    .loc[lambda x: x.param_alpha == lasso_model_cv.best_estimator_.alpha]
    .mean_test_score.values[0]
    * -1
)
'''
#lasso_rmse
# Out:
# '\nlasso_model = ElasticNet(l1_ratio=1, fit_intercept=True)\n\nlasso_model_cv = GridSearchCV(\n    lasso_model,\n    {"alpha": [i / 100 for i in range(1, 26, 1)]},\n    cv=5,\n    scoring="neg_root_mean_squared_error",\n    verbose=3,\n    n_jobs=-1,\n)\n\ny, X = dmatrices("price ~ " + " + ".join(predictors_3), data_train)\ny, X = np.array(y), np.array(X)\n\nlasso_model_cv.fit(X, y.ravel())\n\nlasso_rmse = (\n    pd.DataFrame(lasso_model_cv.cv_results_)\n    .loc[lambda x: x.param_alpha == lasso_model_cv.best_estimator_.alpha]\n    .mean_test_score.values[0]\n    * -1\n)\n'

# %% [markdown]
# # Final Comparison for October

# %%
rmse_values.extend([rmse_lambda_folds.loc[lasso_fit.alpha_].values[0], rf_model_2.cv_results_["mean_test_score"].min() * -1])
model_names = ['OLS 1', 'OLS 2', 'OLS 3', 'LASSO 1', 'RF 3']

df = pd.DataFrame({'Model': model_names, 'Test RMSE': rmse_values})

df['Test RMSE'] = df['Test RMSE'].round(2)

print(df)
# Out:
#      Model  Test RMSE
# 0    OLS 1     791.72
# 1    OLS 2     638.79
# 2    OLS 3     544.59
# 3  LASSO 1     262.93
# 4     RF 3     259.32

# %%
'''
rf_model_2_var_imp_df = (
    pd.DataFrame(
        rf_model_2.best_estimator_.feature_importances_, X.design_info.column_names
    )
    .reset_index()
    .rename({"index": "varname", 0: "imp"}, axis=1)
    .assign(
        imp_percentage=lambda x: x["imp"] / x["imp"].sum(),
        varname=lambda x: x.varname.str.replace(
            "f_room_type[T.", "Room type:", regex=False
        )
        .str.replace("f_neighbourhood_cleansed[T.", "Borough:", regex=False)
        .str.replace("]", "", regex=False),
    )
    .sort_values(by=["imp"], ascending=False)
)

'''
# Out:
# '\nrf_model_2_var_imp_df = (\n    pd.DataFrame(\n        rf_model_2.best_estimator_.feature_importances_, X.design_info.column_names\n    )\n    .reset_index()\n    .rename({"index": "varname", 0: "imp"}, axis=1)\n    .assign(\n        imp_percentage=lambda x: x["imp"] / x["imp"].sum(),\n        varname=lambda x: x.varname.str.replace(\n            "f_room_type[T.", "Room type:", regex=False\n        )\n        .str.replace("f_neighbourhood_cleansed[T.", "Borough:", regex=False)\n        .str.replace("]", "", regex=False),\n    )\n    .sort_values(by=["imp"], ascending=False)\n)\n\n'

# %%
'''
subset_df = rf_model_2_var_imp_df.iloc[:10, :]
color = ['blue']
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(subset_df['varname'], subset_df['imp_percentage'], color=color[0], s=60, label='Variable Importance')
for index, row in subset_df.iterrows():
    ax.plot([row['varname'], row['varname']], [0, row['imp_percentage']], color=color[0], linewidth=2)

ax.set_ylabel('Importance (Percent)')
ax.set_xlabel('Variable Name')
ax.set_title('Variable Importance')
plt.xticks(rotation=90)
ax.grid(True)
plt.tight_layout()
plt.show()
'''
# Out:
# "\nsubset_df = rf_model_2_var_imp_df.iloc[:10, :]\ncolor = ['blue']\nfig, ax = plt.subplots(figsize=(8, 6))\nax.scatter(subset_df['varname'], subset_df['imp_percentage'], color=color[0], s=60, label='Variable Importance')\nfor index, row in subset_df.iterrows():\n    ax.plot([row['varname'], row['varname']], [0, row['imp_percentage']], color=color[0], linewidth=2)\n\nax.set_ylabel('Importance (Percent)')\nax.set_xlabel('Variable Name')\nax.set_title('Variable Importance')\nplt.xticks(rotation=90)\nax.grid(True)\nplt.tight_layout()\nplt.show()\n"

# %% [markdown]
# # SHAP

# %%
import shap
from sklearn.preprocessing import PolynomialFeatures
from sklearn.compose import make_column_transformer
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
categorical_columns = [col for col in predictors_2 if col.startswith("f_")]
numerical_columns = [col for col in predictors_2 if col not in categorical_columns]

# %%
categorical_encoder = OneHotEncoder(handle_unknown="ignore")

preprocessing = ColumnTransformer(
    [
        ("cat", categorical_encoder, categorical_columns),
        ("num", "passthrough", numerical_columns),
    ]
)

rf_best_pipeline = Pipeline(
    [
        ("preprocess", preprocessing),
        ("regressor", rf_model_2.best_estimator_),
    ]
)

# %%
# Fit the ColumnTransformer on the training data
rf_best_pipeline["preprocess"].fit(data_holdout.filter(predictors_2))

# Now you can use it to transform the holdout data
X_encoded = rf_best_pipeline["preprocess"].transform(data_holdout.filter(predictors_2))

new_feature_names = [
    i.replace("cat__", "").replace("num__", "")
    for i in rf_best_pipeline["preprocess"].get_feature_names_out()
]

X_holdout = pd.DataFrame(X_encoded, columns=new_feature_names)
X_holdout = X_holdout.astype(int)

# %%
# Initialize a counter
counter = 0

# Print different categories in categorical columns for train and holdout sets
for col in categorical_columns:
    train_unique = set(data_train[col])
    holdout_unique = set(data_holdout[col])
    diff_categories = train_unique - holdout_unique
    if diff_categories:
        print(f"Different categories in {col}: {diff_categories}")
        counter += len(diff_categories)

print("Total number of different categories:", counter)
# Out:
# Different categories in f_neighbourhood_cleansed: {'Edenwald', 'Holliswood', 'Navy Yard', 'South Beach', 'New Dorp Beach', 'Woodrow', 'Highbridge', 'Coney Island', 'Edgemere', 'Great Kills', 'Castle Hill', 'Rossville', 'Rosebank', 'Westchester Square', 'Graniteville', 'Neponsit', 'Concord', 'Lighthouse Hill', 'Manhattan Beach', 'City Island', 'Riverdale', 'Port Richmond', 'Jamaica Estates', 'Grymes Hill', 'Stapleton', "Bull's Head", 'Co-op City', 'Mount Eden', 'Little Neck', 'Howland Hook', 'University Heights', 'Huguenot', 'East Morrisania', 'Marble Hill', 'Silver Lake', 'New Brighton', 'Dongan Hills', 'West Farms', 'Arden Heights', 'Tottenville', 'New Dorp', 'Grant City', 'Midland Beach', 'Gerritsen Beach', 'Civic Center'}
# Total number of different categories: 45

# %%
for category in diff_categories:
    X_holdout[f"f_neighbourhood_cleansed_{category}"] = 0

# %%
X_holdout['placeholder'] = 0

# %%
explainer = shap.Explainer(rf_best_pipeline["regressor"].predict, X_holdout)
shap_values = explainer(X_holdout)
# Out:
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   1%|▏         | 51/3718 [00:00<?, ?it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   1%|▏         | 53/3718 [00:10<05:01, 12.15it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   1%|▏         | 55/3718 [00:10<09:05,  6.72it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 56/3718 [00:10<09:29,  6.43it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 57/3718 [00:10<09:46,  6.24it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 58/3718 [00:11<10:35,  5.75it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 59/3718 [00:11<11:09,  5.47it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 60/3718 [00:11<11:09,  5.46it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 61/3718 [00:11<12:23,  4.92it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 62/3718 [00:12<12:23,  4.92it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 63/3718 [00:12<11:30,  5.29it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 64/3718 [00:12<11:33,  5.27it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 65/3718 [00:12<12:03,  5.05it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 66/3718 [00:12<11:50,  5.14it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 67/3718 [00:12<11:13,  5.42it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 68/3718 [00:13<11:30,  5.29it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 69/3718 [00:13<11:14,  5.41it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 70/3718 [00:13<11:14,  5.40it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 71/3718 [00:13<11:50,  5.14it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 72/3718 [00:13<11:23,  5.33it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 73/3718 [00:14<11:04,  5.48it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 74/3718 [00:14<12:00,  5.06it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 75/3718 [00:14<11:28,  5.29it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 76/3718 [00:14<11:09,  5.44it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 77/3718 [00:14<11:07,  5.45it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 78/3718 [00:15<12:05,  5.02it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 79/3718 [00:15<11:51,  5.12it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 80/3718 [00:15<11:56,  5.08it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 81/3718 [00:15<12:20,  4.91it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 82/3718 [00:15<12:35,  4.81it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 83/3718 [00:16<11:49,  5.12it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 84/3718 [00:16<13:26,  4.51it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 85/3718 [00:16<12:46,  4.74it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 86/3718 [00:16<12:04,  5.01it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 87/3718 [00:16<11:54,  5.08it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 88/3718 [00:17<11:46,  5.14it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 89/3718 [00:17<12:13,  4.95it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 90/3718 [00:17<13:07,  4.61it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 91/3718 [00:17<12:50,  4.71it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   2%|▏         | 92/3718 [00:17<12:26,  4.86it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 93/3718 [00:18<12:56,  4.67it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 94/3718 [00:18<12:06,  4.99it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 95/3718 [00:18<12:06,  4.99it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 96/3718 [00:18<12:40,  4.76it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 97/3718 [00:18<11:43,  5.15it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 98/3718 [00:19<11:38,  5.19it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 99/3718 [00:19<12:45,  4.73it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 100/3718 [00:19<13:10,  4.58it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 101/3718 [00:19<13:25,  4.49it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 102/3718 [00:20<13:22,  4.51it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 103/3718 [00:20<12:47,  4.71it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 104/3718 [00:20<12:53,  4.67it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 105/3718 [00:20<12:12,  4.93it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 106/3718 [00:20<12:08,  4.96it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 107/3718 [00:21<13:12,  4.56it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 108/3718 [00:21<13:08,  4.58it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 109/3718 [00:21<12:31,  4.80it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 110/3718 [00:21<12:27,  4.83it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 111/3718 [00:21<12:29,  4.81it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 112/3718 [00:22<11:28,  5.24it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 113/3718 [00:22<11:13,  5.35it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 114/3718 [00:22<11:47,  5.09it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 115/3718 [00:22<11:33,  5.19it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 116/3718 [00:22<10:53,  5.51it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 117/3718 [00:22<10:44,  5.58it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 118/3718 [00:23<11:44,  5.11it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 119/3718 [00:23<11:15,  5.32it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 120/3718 [00:23<10:57,  5.48it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 121/3718 [00:23<10:32,  5.69it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 122/3718 [00:23<11:01,  5.43it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 123/3718 [00:24<11:24,  5.25it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 124/3718 [00:24<12:07,  4.94it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 125/3718 [00:24<11:52,  5.04it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 126/3718 [00:24<11:27,  5.22it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 127/3718 [00:24<11:40,  5.13it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 128/3718 [00:25<11:27,  5.22it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 129/3718 [00:25<12:11,  4.91it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   3%|▎         | 130/3718 [00:25<11:36,  5.15it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 131/3718 [00:25<11:07,  5.37it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 132/3718 [00:25<10:35,  5.64it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 133/3718 [00:25<10:18,  5.79it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 134/3718 [00:26<09:43,  6.15it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 135/3718 [00:26<10:43,  5.56it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 136/3718 [00:26<11:07,  5.37it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 137/3718 [00:26<12:01,  4.96it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 138/3718 [00:26<11:28,  5.20it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▎         | 139/3718 [00:27<11:21,  5.25it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 140/3718 [00:27<11:15,  5.30it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 141/3718 [00:27<11:34,  5.15it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 142/3718 [00:27<11:19,  5.26it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 143/3718 [00:27<10:40,  5.58it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 144/3718 [00:28<10:41,  5.57it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 145/3718 [00:28<10:40,  5.58it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 146/3718 [00:28<10:50,  5.49it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 147/3718 [00:28<10:57,  5.43it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 148/3718 [00:28<10:39,  5.58it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 149/3718 [00:28<10:46,  5.52it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 150/3718 [00:29<10:17,  5.78it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 151/3718 [00:29<09:44,  6.10it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 152/3718 [00:29<09:36,  6.18it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 153/3718 [00:29<10:34,  5.62it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 154/3718 [00:29<10:10,  5.84it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 155/3718 [00:29<10:32,  5.63it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 156/3718 [00:30<10:21,  5.73it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 157/3718 [00:30<09:43,  6.11it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 158/3718 [00:30<10:10,  5.83it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 159/3718 [00:30<10:06,  5.87it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 160/3718 [00:30<10:05,  5.88it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 161/3718 [00:30<10:02,  5.91it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 162/3718 [00:31<09:30,  6.23it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 163/3718 [00:31<09:25,  6.29it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 164/3718 [00:31<09:21,  6.33it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 165/3718 [00:31<09:04,  6.52it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 166/3718 [00:31<09:10,  6.46it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   4%|▍         | 167/3718 [00:31<10:06,  5.86it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 168/3718 [00:32<10:25,  5.67it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 169/3718 [00:32<10:02,  5.89it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 170/3718 [00:32<09:49,  6.02it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 171/3718 [00:32<09:52,  5.98it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 172/3718 [00:32<10:13,  5.78it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 173/3718 [00:32<09:54,  5.96it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 174/3718 [00:33<09:58,  5.92it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 175/3718 [00:33<10:31,  5.61it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 176/3718 [00:33<10:21,  5.70it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 177/3718 [00:33<10:13,  5.77it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 178/3718 [00:33<09:59,  5.91it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 179/3718 [00:33<09:43,  6.07it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 180/3718 [00:34<10:41,  5.52it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 181/3718 [00:34<11:46,  5.00it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 182/3718 [00:34<11:48,  4.99it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 183/3718 [00:34<12:08,  4.85it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 184/3718 [00:35<11:56,  4.93it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▍         | 185/3718 [00:35<11:25,  5.15it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 186/3718 [00:35<12:06,  4.86it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 187/3718 [00:35<11:28,  5.13it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 188/3718 [00:35<11:05,  5.30it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 189/3718 [00:35<10:47,  5.45it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 190/3718 [00:36<10:19,  5.69it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 191/3718 [00:36<09:58,  5.89it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 192/3718 [00:36<09:38,  6.10it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 193/3718 [00:36<10:19,  5.69it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 194/3718 [00:36<10:00,  5.87it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 195/3718 [00:36<10:01,  5.86it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 196/3718 [00:37<09:45,  6.02it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 197/3718 [00:37<10:27,  5.61it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 198/3718 [00:37<10:17,  5.70it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 199/3718 [00:37<10:13,  5.74it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 200/3718 [00:37<10:59,  5.33it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 201/3718 [00:38<10:27,  5.60it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 202/3718 [00:38<09:53,  5.92it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 203/3718 [00:38<09:41,  6.04it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   5%|▌         | 204/3718 [00:38<10:17,  5.69it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 205/3718 [00:38<09:57,  5.88it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 206/3718 [00:38<11:01,  5.31it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 207/3718 [00:39<10:23,  5.63it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 208/3718 [00:39<10:03,  5.82it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 209/3718 [00:39<10:21,  5.64it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 210/3718 [00:39<11:18,  5.17it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 211/3718 [00:39<11:40,  5.01it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 212/3718 [00:40<11:07,  5.25it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 213/3718 [00:40<10:46,  5.42it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 214/3718 [00:40<10:03,  5.81it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 215/3718 [00:40<09:30,  6.15it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:   6%|▌         | 216/3718 [00:40<09:57,  5.86it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# ...
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3654/3718 [09:59<00:09,  6.53it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3655/3718 [09:59<00:09,  6.92it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3656/3718 [09:59<00:10,  6.13it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3657/3718 [09:59<00:09,  6.29it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3658/3718 [09:59<00:09,  6.50it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3659/3718 [09:59<00:08,  6.86it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3660/3718 [09:59<00:08,  6.52it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3661/3718 [10:00<00:08,  6.70it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  98%|█████████▊| 3662/3718 [10:00<00:08,  6.64it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3663/3718 [10:00<00:07,  6.90it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3664/3718 [10:00<00:08,  6.62it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3665/3718 [10:00<00:07,  6.98it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3666/3718 [10:00<00:07,  6.92it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3667/3718 [10:00<00:07,  6.45it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3668/3718 [10:01<00:07,  6.88it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3669/3718 [10:01<00:07,  6.79it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3670/3718 [10:01<00:07,  6.28it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▊| 3671/3718 [10:01<00:06,  6.73it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3672/3718 [10:01<00:06,  6.80it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3673/3718 [10:01<00:06,  6.55it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3674/3718 [10:02<00:06,  6.84it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3675/3718 [10:02<00:06,  6.49it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3676/3718 [10:02<00:06,  6.48it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3677/3718 [10:02<00:06,  6.25it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3678/3718 [10:02<00:05,  6.69it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3679/3718 [10:02<00:05,  6.85it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3680/3718 [10:02<00:05,  6.47it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3681/3718 [10:03<00:05,  6.63it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3682/3718 [10:03<00:05,  6.75it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3683/3718 [10:03<00:05,  6.42it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3684/3718 [10:03<00:04,  6.81it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3685/3718 [10:03<00:05,  6.29it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3686/3718 [10:03<00:04,  6.53it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3687/3718 [10:03<00:04,  6.89it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3688/3718 [10:04<00:04,  6.49it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3689/3718 [10:04<00:04,  6.68it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3690/3718 [10:04<00:04,  6.39it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3691/3718 [10:04<00:03,  6.76it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3692/3718 [10:04<00:03,  6.90it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3693/3718 [10:04<00:03,  6.50it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3694/3718 [10:05<00:03,  6.70it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3695/3718 [10:05<00:03,  6.84it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3696/3718 [10:05<00:03,  6.48it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3697/3718 [10:05<00:03,  6.69it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3698/3718 [10:05<00:02,  7.02it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer:  99%|█████████▉| 3699/3718 [10:05<00:02,  6.37it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3700/3718 [10:05<00:02,  6.79it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3701/3718 [10:06<00:02,  6.45it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3702/3718 [10:06<00:02,  6.63it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3703/3718 [10:06<00:02,  6.37it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3704/3718 [10:06<00:02,  6.80it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3705/3718 [10:06<00:02,  6.27it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3706/3718 [10:06<00:01,  6.50it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3707/3718 [10:07<00:01,  6.28it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3708/3718 [10:07<00:01,  6.77it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3709/3718 [10:07<00:01,  6.86it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3710/3718 [10:07<00:01,  6.47it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3711/3718 [10:07<00:01,  6.63it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3712/3718 [10:07<00:00,  6.81it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3713/3718 [10:07<00:00,  6.28it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3714/3718 [10:08<00:00,  6.50it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3715/3718 [10:08<00:00,  6.28it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3716/3718 [10:08<00:00,  6.47it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|█████████▉| 3717/3718 [10:08<00:00,  6.65it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 100%|██████████| 3718/3718 [10:08<00:00,  6.37it/s]X has feature names, but RandomForestRegressor was fitted without feature names
# X has feature names, but RandomForestRegressor was fitted without feature names
# PermutationExplainer explainer: 3719it [10:08,  6.02it/s]

# %%
rf_best_pipeline["preprocess"].fit(data_train.filter(predictors_2))
X_encoded_train = rf_best_pipeline["preprocess"].transform(data_train.filter(predictors_2))

feature_names = [
    i.replace("cat__", "").replace("num__", "")
    for i in rf_best_pipeline["preprocess"].get_feature_names_out()
]

len(feature_names)
# Out:
# 387

# %%
feature_names = set(feature_names)

# %%
holdout_features_encoded = set(X_holdout.columns)
len(holdout_features_encoded)
# Out:
# 388

# %%
missing_features_encoded =  holdout_features_encoded - feature_names

for feature in missing_features_encoded:
    print(feature)
# Out:
# f_neighbourhood_cleansed_Lighthouse Hill

# %%
plt.figure(figsize=(10, 20))  # Adjust the size as needed
shap.plots.beeswarm(shap_values, max_display = 15, color=plt.get_cmap("viridis_r"), show=False)
plt.gcf().tight_layout()  # Adjust the layout to fit the feature names
plt.gcf().savefig('/Users/Admin/Desktop/oct_shap_beeswarm.png')

# %%
plt.figure(figsize=(10, 20))  # Adjust the size as needed
shap.plots.bar(shap_values, show=False)
plt.gcf().tight_layout()  # Adjust the layout to fit the feature names
plt.gcf().savefig('/Users/Admin/Desktop/oct_shap_bar.png')

# %%
plt.figure(figsize=(10, 20))  # Adjust the size as needed
shap.plots.waterfall(shap_values[2], show=False)
plt.gcf().tight_layout()  # Adjust the layout to fit the feature names
plt.gcf().savefig('/Users/Admin/Desktop/oct_shap_waterfall_2.png')
